# %% [markdown]
# ### All import statements exists here

# %%
import geocoder
import sys
import tkinter
import tkinter.messagebox
from tkintermapview import TkinterMapView
import geocoder
from geopy.geocoders import Nominatim
import datetime as dt
import requests
import json
import pprint

# %% [markdown]
# ## Find the Satellites that are above our head
# ### Change the latitude and longitude here

# %%
class satlAboveHead:
    # geocoder.ip('me') is used to get current location in latitude and longitude
    locPlaceHldr = geocoder.ip('me')
    location = locPlaceHldr.latlng
    print(" The Current Location is: {}".format(location))
    # print("{}, {}".format(location[0], location[1]))



    url_str = "http://api.n2yo.com/rest/v1/satellite/above/"

    # USing the below line for manual testing only
    # latitude, longitude = "44.2367", "66.3287"

    latitude, longitude = str(location[0]), str(location[1])

    latitude = str(32.2733)
    longitude = str(75.6522)


    # This below angle value  25 would provide a search radius of 466 km 
                  #           08 would provide a  radius of 158km 
    #      at altitude of 1000km from observer's posn
    #      30 refers to military satellites.
    leading_url = "0/15/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7"
    final_url = url_str+latitude+"/"+longitude+"/"+leading_url
    print(url_str+latitude+"/"+longitude+"/"+leading_url)

    above_satellite_request = requests.get(final_url)
    print("Response from making REST call {}".format(above_satellite_request))

    if(above_satellite_request.json() is None):
        tkinter.messagebox.showwarning(title = "BLZ", message = "You are in Black Out Zone")



 
    
    above_no_of_satellites = above_satellite_request.json().get('info')['satcount']

    print("There are \t {} \t satl in the orbit above you. \n".format(above_no_of_satellites))
# Out:
#  The Current Location is: [19.0728, 72.8826]
# http://api.n2yo.com/rest/v1/satellite/above/32.2733/75.6522/0/15/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
# Response from making REST call <Response [200]>
# There are 	 2 	 satl in the orbit above you.

# %%
# !pip install geocoder
# !pip install sys
# !pip install tkinter
# !pip install Nominatim
# !pip install TkinterMapView
# !pip install datetime
# !pip install requests
# !pip install json
# !pip install pprint

# %% [markdown]
# ## Retreiving the positions of the satl mentioned above

# %%
class getSatlPosn:
    obj = satlAboveHead()
    satlPosnData = []
    gps_position_data_from_above_satellite = []
    # This initialization would be done only if input is not None 
    # print("{} {}".format(type(obj.above_satellite_request.json()), obj.above_satellite_request.json()))
    # print(type(obj.above_satellite_request))

    if( bool(obj.above_satellite_request)): 
        gps_position_data_from_above_satellite = obj.above_satellite_request.json()['above']
    else:
        satlPosnData = None
        print("Value with None exists")
    
    # print(gps_position_data.keys())
    # print(gps_position_data_from_above_satellite)
    print("There are {} Military Satellites on top of your head. \n".format(obj.above_no_of_satellites)) # THis returns the count of military satellites
    
    url_str = "http://api.n2yo.com/rest/v1/satellite/positions/"
    latitude = str(32.2733)
    longitude = str(75.6522)
    leading_url = "0/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7"

    print("\n Satellites are revolving on top of india: ")
    print(gps_position_data_from_above_satellite)
    for i in gps_position_data_from_above_satellite:
        print("\n {}".format(i['satid']) )

        sat_id = str(i['satid'])
        final_url = url_str+sat_id+"/"+latitude+"/"+longitude+"/"+leading_url
        print(final_url+"\n")
        # Making the REST call
        req = requests.get(final_url)
        pprint.pprint(req.json())
        # print("\n")
        satlPosnData.insert(i['satid'],req.json())
        
    # print(satlPosnData)
# Out:
# There are 2 Military Satellites on top of your head.
#
#
#  Satellites are revolving on top of india:
# [{'satid': 12078, 'satname': 'COSMOS 1223', 'intDesignator': '1980-095A', 'launchDate': '1980-11-27', 'satlat': 37.0412, 'satlng': 64.0911, 'satalt': 31489.9252}, {'satid': 16849, 'satname': 'COSMOS 1761', 'intDesignator': '1986-050A', 'launchDate': '1986-07-05', 'satlat': 26.0491, 'satlng': 84.011, 'satalt': 18252.1356}]
#
#  12078
# http://api.n2yo.com/rest/v1/satellite/positions/12078/32.2733/75.6522/0/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
#
# {'info': {'satid': 12078, 'satname': 'COSMOS 1223', 'transactionscount': 67},
#  'positions': [{'azimuth': 299.77,
#                 'dec': 37.89351885,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.21411474,
#                 'sataltitude': 31492.13,
#                 'satlatitude': 37.03138025,
#                 'satlongitude': 64.0880357,
#                 'timestamp': 1688836899},
#                {'azimuth': 299.75,
#                 'dec': 37.88953458,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.21553636,
#                 'sataltitude': 31492.87,
#                 'satlatitude': 37.02811939,
#                 'satlongitude': 64.08561232,
#                 'timestamp': 1688836900},
#                {'azimuth': 299.73,
#                 'dec': 37.88555045,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.21695777,
#                 'sataltitude': 31493.61,
#                 'satlatitude': 37.02485864,
#                 'satlongitude': 64.08318872,
#                 'timestamp': 1688836901},
#                {'azimuth': 299.71,
#                 'dec': 37.88156647,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.21837894,
#                 'sataltitude': 31494.34,
#                 'satlatitude': 37.02159799,
#                 'satlongitude': 64.08076491,
#                 'timestamp': 1688836902},
#                {'azimuth': 299.69,
#                 'dec': 37.87758264,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.21979989,
#                 'sataltitude': 31495.08,
#                 'satlatitude': 37.01833744,
#                 'satlongitude': 64.07834088,
#                 'timestamp': 1688836903},
#                {'azimuth': 299.67,
#                 'dec': 37.87359896,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.2212206,
#                 'sataltitude': 31495.81,
#                 'satlatitude': 37.01507698,
#                 'satlongitude': 64.07591663,
#                 'timestamp': 1688836904},
#                {'azimuth': 299.65,
#                 'dec': 37.86961527,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.22264115,
#                 'sataltitude': 31496.55,
#                 'satlatitude': 37.0118165,
#                 'satlongitude': 64.07349206,
#                 'timestamp': 1688836905},
#                {'azimuth': 299.63,
#                 'dec': 37.86563188,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.22406142,
#                 'sataltitude': 31497.28,
#                 'satlatitude': 37.00855625,
#                 'satlongitude': 64.07106737,
#                 'timestamp': 1688836906},
#                {'azimuth': 299.61,
#                 'dec': 37.86164864,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.22548146,
#                 'sataltitude': 31498.02,
#                 'satlatitude': 37.0052961,
#                 'satlongitude': 64.06864247,
#                 'timestamp': 1688836907},
#                {'azimuth': 299.59,
#                 'dec': 37.85766555,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.22690127,
#                 'sataltitude': 31498.76,
#                 'satlatitude': 37.00203606,
#                 'satlongitude': 64.06621734,
#                 'timestamp': 1688836908},
#                {'azimuth': 299.57,
#                 'dec': 37.85368261,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.22832085,
#                 'sataltitude': 31499.49,
#                 'satlatitude': 36.99877611,
#                 'satlongitude': 64.063792,
#                 'timestamp': 1688836909},
#                {'azimuth': 299.54,
#                 'dec': 37.84969981,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.22974021,
#                 'sataltitude': 31500.22,
#                 'satlatitude': 36.99551626,
#                 'satlongitude': 64.06136644,
#                 'timestamp': 1688836910},
#                {'azimuth': 299.52,
#                 'dec': 37.84571716,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.23115934,
#                 'sataltitude': 31500.96,
#                 'satlatitude': 36.99225652,
#                 'satlongitude': 64.05894066,
#                 'timestamp': 1688836911},
#                {'azimuth': 299.5,
#                 'dec': 37.8417345,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 248.2325783,
#                 'sataltitude': 31501.69,
#                 'satlatitude': 36.98899674,
#                 'satlongitude': 64.05651457,
#                 'timestamp': 1688836912},
#                {'azimuth': 299.48,
#                 'dec': 37.83775214,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.23399698,
#                 'sataltitude': 31502.43,
#                 'satlatitude': 36.98573719,
#                 'satlongitude': 64.05408835,
#                 'timestamp': 1688836913},
#                {'azimuth': 299.46,
#                 'dec': 37.83376993,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.23541543,
#                 'sataltitude': 31503.16,
#                 'satlatitude': 36.98247775,
#                 'satlongitude': 64.05166192,
#                 'timestamp': 1688836914},
#                {'azimuth': 299.44,
#                 'dec': 37.82978787,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.23683366,
#                 'sataltitude': 31503.9,
#                 'satlatitude': 36.97921841,
#                 'satlongitude': 64.04923527,
#                 'timestamp': 1688836915},
#                {'azimuth': 299.42,
#                 'dec': 37.82580596,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.23825166,
#                 'sataltitude': 31504.63,
#                 'satlatitude': 36.97595916,
#                 'satlongitude': 64.0468084,
#                 'timestamp': 1688836916},
#                {'azimuth': 299.4,
#                 'dec': 37.82182419,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.23966943,
#                 'sataltitude': 31505.36,
#                 'satlatitude': 36.97270002,
#                 'satlongitude': 64.04438131,
#                 'timestamp': 1688836917},
#                {'azimuth': 299.38,
#                 'dec': 37.81784257,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.24108698,
#                 'sataltitude': 31506.1,
#                 'satlatitude': 36.96944098,
#                 'satlongitude': 64.04195401,
#                 'timestamp': 1688836918},
#                {'azimuth': 299.36,
#                 'dec': 37.81386094,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.24250436,
#                 'sataltitude': 31506.83,
#                 'satlatitude': 36.9661819,
#                 'satlongitude': 64.03952639,
#                 'timestamp': 1688836919},
#                {'azimuth': 299.34,
#                 'dec': 37.80987977,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.2439214,
#                 'sataltitude': 31507.57,
#                 'satlatitude': 36.96292319,
#                 'satlongitude': 64.03709875,
#                 'timestamp': 1688836920},
#                {'azimuth': 299.32,
#                 'dec': 37.80589843,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.24533832,
#                 'sataltitude': 31508.3,
#                 'satlatitude': 36.95966432,
#                 'satlongitude': 64.03467069,
#                 'timestamp': 1688836921},
#                {'azimuth': 299.3,
#                 'dec': 37.8019174,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.24675497,
#                 'sataltitude': 31509.03,
#                 'satlatitude': 36.95640568,
#                 'satlongitude': 64.03224252,
#                 'timestamp': 1688836922},
#                {'azimuth': 299.28,
#                 'dec': 37.79793651,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.24817138,
#                 'sataltitude': 31509.77,
#                 'satlatitude': 36.95314714,
#                 'satlongitude': 64.02981412,
#                 'timestamp': 1688836923},
#                {'azimuth': 299.26,
#                 'dec': 37.79395578,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.24958758,
#                 'sataltitude': 31510.5,
#                 'satlatitude': 36.9498887,
#                 'satlongitude': 64.02738552,
#                 'timestamp': 1688836924},
#                {'azimuth': 299.24,
#                 'dec': 37.78997519,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.25100354,
#                 'sataltitude': 31511.23,
#                 'satlatitude': 36.94663036,
#                 'satlongitude': 64.02495669,
#                 'timestamp': 1688836925},
#                {'azimuth': 299.22,
#                 'dec': 37.78599458,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.25241934,
#                 'sataltitude': 31511.96,
#                 'satlatitude': 36.94337199,
#                 'satlongitude': 64.02252755,
#                 'timestamp': 1688836926},
#                {'azimuth': 299.2,
#                 'dec': 37.78201444,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.2538348,
#                 'sataltitude': 31512.7,
#                 'satlatitude': 36.94011398,
#                 'satlongitude': 64.02009838,
#                 'timestamp': 1688836927},
#                {'azimuth': 299.18,
#                 'dec': 37.77803413,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 248.25525015,
#                 'sataltitude': 31513.43,
#                 'satlatitude': 36.93685582,
#                 'satlongitude': 64.01766881,
#                 'timestamp': 1688836928}]}
#
#  16849
# http://api.n2yo.com/rest/v1/satellite/positions/16849/32.2733/75.6522/0/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
#
# {'info': {'satid': 16849, 'satname': 'COSMOS 1761', 'transactionscount': 67},
#  'positions': [{'azimuth': 128.44,
#                 'dec': 23.76126711,
#                 'eclipsed': False,
#                 'elevation': 77.08,
#                 'ra': 273.26076249,
#                 'sataltitude': 18261.78,
#                 'satlatitude': 26.01992085,
#                 'satlongitude': 84.01201045,
#                 'timestamp': 1688836900},
#                {'azimuth': 128.47,
#                 'dec': 23.75181365,
#                 'eclipsed': False,
#                 'elevation': 77.07,
#                 'ra': 273.26332008,
#                 'sataltitude': 18264.19,
#                 'satlatitude': 26.01262176,
#                 'satlongitude': 84.01122454,
#                 'timestamp': 1688836901},
#                {'azimuth': 128.51,
#                 'dec': 23.74236262,
#                 'eclipsed': False,
#                 'elevation': 77.07,
#                 'ra': 273.26587667,
#                 'sataltitude': 18266.6,
#                 'satlatitude': 26.00532403,
#                 'satlongitude': 84.01043754,
#                 'timestamp': 1688836902},
#                {'azimuth': 128.54,
#                 'dec': 23.73291402,
#                 'eclipsed': False,
#                 'elevation': 77.06,
#                 'ra': 273.26843227,
#                 'sataltitude': 18269.01,
#                 'satlatitude': 25.99802765,
#                 'satlongitude': 84.00964946,
#                 'timestamp': 1688836903},
#                {'azimuth': 128.58,
#                 'dec': 23.72346784,
#                 'eclipsed': False,
#                 'elevation': 77.06,
#                 'ra': 273.27098687,
#                 'sataltitude': 18271.42,
#                 'satlatitude': 25.99073262,
#                 'satlongitude': 84.0088603,
#                 'timestamp': 1688836904},
#                {'azimuth': 128.61,
#                 'dec': 23.71402371,
#                 'eclipsed': False,
#                 'elevation': 77.05,
#                 'ra': 273.27354058,
#                 'sataltitude': 18273.83,
#                 'satlatitude': 25.98343864,
#                 'satlongitude': 84.00807002,
#                 'timestamp': 1688836905},
#                {'azimuth': 128.65,
#                 'dec': 23.70458239,
#                 'eclipsed': False,
#                 'elevation': 77.05,
#                 'ra': 273.27609319,
#                 'sataltitude': 18276.24,
#                 'satlatitude': 25.9761463,
#                 'satlongitude': 84.00727869,
#                 'timestamp': 1688836906},
#                {'azimuth': 128.68,
#                 'dec': 23.69514349,
#                 'eclipsed': False,
#                 'elevation': 77.04,
#                 'ra': 273.27864481,
#                 'sataltitude': 18278.65,
#                 'satlatitude': 25.96885531,
#                 'satlongitude': 84.00648628,
#                 'timestamp': 1688836907},
#                {'azimuth': 128.72,
#                 'dec': 23.68570702,
#                 'eclipsed': False,
#                 'elevation': 77.03,
#                 'ra': 273.28119544,
#                 'sataltitude': 18281.06,
#                 'satlatitude': 25.96156567,
#                 'satlongitude': 84.00569279,
#                 'timestamp': 1688836908},
#                {'azimuth': 128.75,
#                 'dec': 23.67627296,
#                 'eclipsed': False,
#                 'elevation': 77.03,
#                 'ra': 273.28374507,
#                 'sataltitude': 18283.47,
#                 'satlatitude': 25.95427737,
#                 'satlongitude': 84.00489822,
#                 'timestamp': 1688836909},
#                {'azimuth': 128.78,
#                 'dec': 23.66684133,
#                 'eclipsed': False,
#                 'elevation': 77.02,
#                 'ra': 273.28629372,
#                 'sataltitude': 18285.88,
#                 'satlatitude': 25.94699042,
#                 'satlongitude': 84.00410257,
#                 'timestamp': 1688836910},
#                {'azimuth': 128.82,
#                 'dec': 23.65741211,
#                 'eclipsed': False,
#                 'elevation': 77.02,
#                 'ra': 273.28884137,
#                 'sataltitude': 18288.29,
#                 'satlatitude': 25.93970481,
#                 'satlongitude': 84.00330585,
#                 'timestamp': 1688836911},
#                {'azimuth': 128.85,
#                 'dec': 23.64798494,
#                 'eclipsed': False,
#                 'elevation': 77.01,
#                 'ra': 273.29138814,
#                 'sataltitude': 18290.7,
#                 'satlatitude': 25.93242026,
#                 'satlongitude': 84.00250801,
#                 'timestamp': 1688836912},
#                {'azimuth': 128.89,
#                 'dec': 23.63856056,
#                 'eclipsed': False,
#                 'elevation': 77.01,
#                 'ra': 273.29393382,
#                 'sataltitude': 18293.1,
#                 'satlatitude': 25.92513734,
#                 'satlongitude': 84.00170913,
#                 'timestamp': 1688836913},
#                {'azimuth': 128.92,
#                 'dec': 23.6291386,
#                 'eclipsed': False,
#                 'elevation': 77,
#                 'ra': 273.29647851,
#                 'sataltitude': 18295.51,
#                 'satlatitude': 25.91785576,
#                 'satlongitude': 84.00090917,
#                 'timestamp': 1688836914},
#                {'azimuth': 128.96,
#                 'dec': 23.61971905,
#                 'eclipsed': False,
#                 'elevation': 77,
#                 'ra': 273.29902221,
#                 'sataltitude': 18297.92,
#                 'satlatitude': 25.91057554,
#                 'satlongitude': 84.00010813,
#                 'timestamp': 1688836915},
#                {'azimuth': 128.99,
#                 'dec': 23.61030192,
#                 'eclipsed': False,
#                 'elevation': 76.99,
#                 'ra': 273.30156492,
#                 'sataltitude': 18300.33,
#                 'satlatitude': 25.90329665,
#                 'satlongitude': 83.99930602,
#                 'timestamp': 1688836916},
#                {'azimuth': 129.03,
#                 'dec': 23.6008872,
#                 'eclipsed': False,
#                 'elevation': 76.99,
#                 'ra': 273.30410665,
#                 'sataltitude': 18302.73,
#                 'satlatitude': 25.89601911,
#                 'satlongitude': 83.99850284,
#                 'timestamp': 1688836917},
#                {'azimuth': 129.06,
#                 'dec': 23.59147489,
#                 'eclipsed': False,
#                 'elevation': 76.98,
#                 'ra': 273.3066474,
#                 'sataltitude': 18305.14,
#                 'satlatitude': 25.8887429,
#                 'satlongitude': 83.99769858,
#                 'timestamp': 1688836918},
#                {'azimuth': 129.1,
#                 'dec': 23.58206461,
#                 'eclipsed': False,
#                 'elevation': 76.97,
#                 'ra': 273.30918726,
#                 'sataltitude': 18307.55,
#                 'satlatitude': 25.88146775,
#                 'satlongitude': 83.99689321,
#                 'timestamp': 1688836919},
#                {'azimuth': 129.13,
#                 'dec': 23.57265751,
#                 'eclipsed': False,
#                 'elevation': 76.97,
#                 'ra': 273.31172594,
#                 'sataltitude': 18309.96,
#                 'satlatitude': 25.87419453,
#                 'satlongitude': 83.99608684,
#                 'timestamp': 1688836920},
#                {'azimuth': 129.17,
#                 'dec': 23.56325205,
#                 'eclipsed': False,
#                 'elevation': 76.96,
#                 'ra': 273.31426383,
#                 'sataltitude': 18312.36,
#                 'satlatitude': 25.86692206,
#                 'satlongitude': 83.99527933,
#                 'timestamp': 1688836921},
#                {'azimuth': 129.2,
#                 'dec': 23.55384938,
#                 'eclipsed': False,
#                 'elevation': 76.96,
#                 'ra': 273.31680065,
#                 'sataltitude': 18314.77,
#                 'satlatitude': 25.85965122,
#                 'satlongitude': 83.99447079,
#                 'timestamp': 1688836922},
#                {'azimuth': 129.23,
#                 'dec': 23.54444911,
#                 'eclipsed': False,
#                 'elevation': 76.95,
#                 'ra': 273.31933648,
#                 'sataltitude': 18317.18,
#                 'satlatitude': 25.85238172,
#                 'satlongitude': 83.99366117,
#                 'timestamp': 1688836923},
#                {'azimuth': 129.27,
#                 'dec': 23.53505126,
#                 'eclipsed': False,
#                 'elevation': 76.95,
#                 'ra': 273.32187133,
#                 'sataltitude': 18319.58,
#                 'satlatitude': 25.84511356,
#                 'satlongitude': 83.99285048,
#                 'timestamp': 1688836924},
#                {'azimuth': 129.3,
#                 'dec': 23.5256558,
#                 'eclipsed': False,
#                 'elevation': 76.94,
#                 'ra': 273.3244052,
#                 'sataltitude': 18321.99,
#                 'satlatitude': 25.83784675,
#                 'satlongitude': 83.99203872,
#                 'timestamp': 1688836925},
#                {'azimuth': 129.34,
#                 'dec': 23.51626237,
#                 'eclipsed': False,
#                 'elevation': 76.94,
#                 'ra': 273.3269382,
#                 'sataltitude': 18324.39,
#                 'satlatitude': 25.83058098,
#                 'satlongitude': 83.99122586,
#                 'timestamp': 1688836926},
#                {'azimuth': 129.37,
#                 'dec': 23.5068721,
#                 'eclipsed': False,
#                 'elevation': 76.93,
#                 'ra': 273.32947001,
#                 'sataltitude': 18326.8,
#                 'satlatitude': 25.82331713,
#                 'satlongitude': 83.990412,
#                 'timestamp': 1688836927},
#                {'azimuth': 129.4,
#                 'dec': 23.49748347,
#                 'eclipsed': False,
#                 'elevation': 76.92,
#                 'ra': 273.33200105,
#                 'sataltitude': 18329.2,
#                 'satlatitude': 25.81605403,
#                 'satlongitude': 83.98959701,
#                 'timestamp': 1688836928},
#                {'azimuth': 129.44,
#                 'dec': 23.48809763,
#                 'eclipsed': False,
#                 'elevation': 76.92,
#                 'ra': 273.33453101,
#                 'sataltitude': 18331.61,
#                 'satlatitude': 25.80879256,
#                 'satlongitude': 83.98878098,
#                 'timestamp': 1688836929}]}

# %% [markdown]
# ## The User Interface

# %%
print(len(getSatlPosn.satlPosnData))
print(getSatlPosn.satlPosnData)
# Out:
# 2
# [{'info': {'satname': 'COSMOS 1223', 'satid': 12078, 'transactionscount': 67}, 'positions': [{'satlatitude': 37.03138025, 'satlongitude': 64.0880357, 'sataltitude': 31492.13, 'azimuth': 299.77, 'elevation': 77.24, 'ra': 248.21411474, 'dec': 37.89351885, 'timestamp': 1688836899, 'eclipsed': False}, {'satlatitude': 37.02811939, 'satlongitude': 64.08561232, 'sataltitude': 31492.87, 'azimuth': 299.75, 'elevation': 77.24, 'ra': 248.21553636, 'dec': 37.88953458, 'timestamp': 1688836900, 'eclipsed': False}, {'satlatitude': 37.02485864, 'satlongitude': 64.08318872, 'sataltitude': 31493.61, 'azimuth': 299.73, 'elevation': 77.24, 'ra': 248.21695777, 'dec': 37.88555045, 'timestamp': 1688836901, 'eclipsed': False}, {'satlatitude': 37.02159799, 'satlongitude': 64.08076491, 'sataltitude': 31494.34, 'azimuth': 299.71, 'elevation': 77.24, 'ra': 248.21837894, 'dec': 37.88156647, 'timestamp': 1688836902, 'eclipsed': False}, {'satlatitude': 37.01833744, 'satlongitude': 64.07834088, 'sataltitude': 31495.08, 'azimuth': 299.69, 'elevation': 77.24, 'ra': 248.21979989, 'dec': 37.87758264, 'timestamp': 1688836903, 'eclipsed': False}, {'satlatitude': 37.01507698, 'satlongitude': 64.07591663, 'sataltitude': 31495.81, 'azimuth': 299.67, 'elevation': 77.24, 'ra': 248.2212206, 'dec': 37.87359896, 'timestamp': 1688836904, 'eclipsed': False}, {'satlatitude': 37.0118165, 'satlongitude': 64.07349206, 'sataltitude': 31496.55, 'azimuth': 299.65, 'elevation': 77.24, 'ra': 248.22264115, 'dec': 37.86961527, 'timestamp': 1688836905, 'eclipsed': False}, {'satlatitude': 37.00855625, 'satlongitude': 64.07106737, 'sataltitude': 31497.28, 'azimuth': 299.63, 'elevation': 77.24, 'ra': 248.22406142, 'dec': 37.86563188, 'timestamp': 1688836906, 'eclipsed': False}, {'satlatitude': 37.0052961, 'satlongitude': 64.06864247, 'sataltitude': 31498.02, 'azimuth': 299.61, 'elevation': 77.24, 'ra': 248.22548146, 'dec': 37.86164864, 'timestamp': 1688836907, 'eclipsed': False}, {'satlatitude': 37.00203606, 'satlongitude': 64.06621734, 'sataltitude': 31498.76, 'azimuth': 299.59, 'elevation': 77.24, 'ra': 248.22690127, 'dec': 37.85766555, 'timestamp': 1688836908, 'eclipsed': False}, {'satlatitude': 36.99877611, 'satlongitude': 64.063792, 'sataltitude': 31499.49, 'azimuth': 299.57, 'elevation': 77.24, 'ra': 248.22832085, 'dec': 37.85368261, 'timestamp': 1688836909, 'eclipsed': False}, {'satlatitude': 36.99551626, 'satlongitude': 64.06136644, 'sataltitude': 31500.22, 'azimuth': 299.54, 'elevation': 77.24, 'ra': 248.22974021, 'dec': 37.84969981, 'timestamp': 1688836910, 'eclipsed': False}, {'satlatitude': 36.99225652, 'satlongitude': 64.05894066, 'sataltitude': 31500.96, 'azimuth': 299.52, 'elevation': 77.24, 'ra': 248.23115934, 'dec': 37.84571716, 'timestamp': 1688836911, 'eclipsed': False}, {'satlatitude': 36.98899674, 'satlongitude': 64.05651457, 'sataltitude': 31501.69, 'azimuth': 299.5, 'elevation': 77.24, 'ra': 248.2325783, 'dec': 37.8417345, 'timestamp': 1688836912, 'eclipsed': False}, {'satlatitude': 36.98573719, 'satlongitude': 64.05408835, 'sataltitude': 31502.43, 'azimuth': 299.48, 'elevation': 77.23, 'ra': 248.23399698, 'dec': 37.83775214, 'timestamp': 1688836913, 'eclipsed': False}, {'satlatitude': 36.98247775, 'satlongitude': 64.05166192, 'sataltitude': 31503.16, 'azimuth': 299.46, 'elevation': 77.23, 'ra': 248.23541543, 'dec': 37.83376993, 'timestamp': 1688836914, 'eclipsed': False}, {'satlatitude': 36.97921841, 'satlongitude': 64.04923527, 'sataltitude': 31503.9, 'azimuth': 299.44, 'elevation': 77.23, 'ra': 248.23683366, 'dec': 37.82978787, 'timestamp': 1688836915, 'eclipsed': False}, {'satlatitude': 36.97595916, 'satlongitude': 64.0468084, 'sataltitude': 31504.63, 'azimuth': 299.42, 'elevation': 77.23, 'ra': 248.23825166, 'dec': 37.82580596, 'timestamp': 1688836916, 'eclipsed': False}, {'satlatitude': 36.97270002, 'satlongitude': 64.04438131, 'sataltitude': 31505.36, 'azimuth': 299.4, 'elevation': 77.23, 'ra': 248.23966943, 'dec': 37.82182419, 'timestamp': 1688836917, 'eclip ...

# %%
import tkinter

class App(tkinter.Tk):

    obj = getSatlPosn()
    APP_NAME = " Satellite orbits"
    WIDTH = 800
    HEIGHT = 750
    # Below is the sample data used off the REST call made 
    # https://api.n2yo.com/rest/v1/satellite/positions/25544/41.702/-76.014/ {} / {} /&apiKey=589P8Q-SDRYX8-L842ZD-5Z9
    if( obj.satlPosnData is not None):
        positions = obj.satlPosnData
    else:

        tkinter.messagebox.showwarning(title = "BLZ", message = "Not in Black Out Zone")

# {
#     # positions = [ 
#     #     {
#     #         "satlatitude": 48.93831553,
#     #         "satlongitude": 32.20823369,
#     #         "sataltitude": 423.48,
#     #         "azimuth": 41.74,
#     #         "elevation": -32.18,
#     #         "ra": 42.47092063,
#     #         "dec": 6.65551562,
#     #         "timestamp": 1682065020,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.91655743,
#     #         "satlongitude": 32.29639533,
#     #         "sataltitude": 423.47,
#     #         "azimuth": 41.72,
#     #         "elevation": -32.21,
#     #         "ra": 42.50814991,
#     #         "dec": 6.63768375,
#     #         "timestamp": 1682065021,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.89472547,
#     #         "satlongitude": 32.3844769,
#     #         "sataltitude": 423.46,
#     #         "azimuth": 41.7,
#     #         "elevation": -32.24,
#     #         "ra": 42.54534878,
#     #         "dec": 6.61983002,
#     #         "timestamp": 1682065022,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.87281887,
#     #         "satlongitude": 32.4724818,
#     #         "sataltitude": 423.45,
#     #         "azimuth": 41.68,
#     #         "elevation": -32.27,
#     #         "ra": 42.58251879,
#     #         "dec": 6.60195376,
#     #         "timestamp": 1682065023,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.85083954,
#     #         "satlongitude": 32.5604028,
#     #         "sataltitude": 423.44,
#     #         "azimuth": 41.65,
#     #         "elevation": -32.3,
#     #         "ra": 42.61965701,
#     #         "dec": 6.58405647,
#     #         "timestamp": 1682065024,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.82878669,
#     #         "satlongitude": 32.64824333,
#     #         "sataltitude": 423.43,
#     #         "azimuth": 41.63,
#     #         "elevation": -32.34,
#     #         "ra": 42.65676499,
#     #         "dec": 6.5661375,
#     #         "timestamp": 1682065025,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.80666046,
#     #         "satlongitude": 32.73600323,
#     #         "sataltitude": 423.42,
#     #         "azimuth": 41.61,
#     #         "elevation": -32.37,
#     #         "ra": 42.6938428,
#     #         "dec": 6.54819689,
#     #         "timestamp": 1682065026,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.78446096,
#     #         "satlongitude": 32.82368238,
#     #         "sataltitude": 423.41,
#     #         "azimuth": 41.58,
#     #         "elevation": -32.4,
#     #         "ra": 42.73089049,
#     #         "dec": 6.53023472,
#     #         "timestamp": 1682065027,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.76218832,
#     #         "satlongitude": 32.91128064,
#     #         "sataltitude": 423.41,
#     #         "azimuth": 41.56,
#     #         "elevation": -32.43,
#     #         "ra": 42.76790814,
#     #         "dec": 6.51225103,
#     #         "timestamp": 1682065028,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.73984265,
#     #         "satlongitude": 32.99879788,
#     #         "sataltitude": 423.4,
#     #         "azimuth": 41.54,
#     #         "elevation": -32.46,
#     #         "ra": 42.8048958,
#     #         "dec": 6.49424589,
#     #         "timestamp": 1682065029,
#     #         "eclipsed": False
#     #     }
#     # ]
# }

    
    def __init__(self, *args, **kwargs):
        tkinter.Tk.__init__(self, *args, **kwargs)

        self.title(self.APP_NAME)
        self.geometry(f"{self.WIDTH}x{self.HEIGHT}")

        self.protocol("WM_DELETE_WINDOW", self.on_closing)
        self.bind("<Return>", self.search)

        if sys.platform == "darwin":
            self.bind("<Command-q>", self.on_closing)
            self.bind("<Command-w>", self.on_closing)

        self.grid_columnconfigure(0, weight=1)
        self.grid_columnconfigure(1, weight=0)
        self.grid_columnconfigure(2, weight=0)
        self.grid_rowconfigure(1, weight=1)
        
        self.search_bar = tkinter.Entry(self, width=50) 
        # Here we can give input in terms of ( 40.714, -74.006) latitude, longitude
        self.search_bar.grid(row=0, column=0, pady=10, padx=10, sticky="we")
        self.search_bar.focus()

        self.search_bar_button = tkinter.Button(
            master=self, width=8, text="Search", command=self.search)
        self.search_bar_button.grid(row=0, column=1, pady=10, padx=10)

        self.search_bar_clear = tkinter.Button(
            master=self, width=8, text="Clear", command=self.clear)
        self.search_bar_clear.grid(row=0, column=2, pady=10, padx=10)

        self.map_widget = TkinterMapView(
            width=self.WIDTH, height=600, corner_radius=0)
        self.map_widget.grid(row=1, column=0, columnspan=3, sticky="nsew")

        self.marker_list_box = tkinter.Listbox(self, height=8)
        self.marker_list_box.grid(row=2, column=0, columnspan=1, sticky="ew", padx=10, pady=10)

        self.listbox_button_frame = tkinter.Frame(master=self)
        self.listbox_button_frame.grid( 
            row=2, column=1, sticky="nsew", columnspan=2)

        self.listbox_button_frame.grid_columnconfigure(0, weight=1)

        self.save_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="save current marker",
                                                 command=self.save_marker)
        self.save_marker_button.grid(row=0, column=0, pady=10, padx=10)

        self.clear_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="get satellite coordinates",
                                                  command=self.get_satellite_coordinates)
        self.clear_marker_button.grid(row=1, column=0, pady=10, padx=10)

        self.connect_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="connect marker with path",
                                                    command=self.connect_marker)
        self.connect_marker_button.grid(row=2, column=0, pady=10, padx=10)

        # This is the default addresss that the map would show
        self.map_widget.set_address("Jammu, India")

        self.marker_list = []
        self.marker_path = None

        self.search_marker = None
        self.search_in_progress = False

    def search(self, event=None):
        if not self.search_in_progress:   # IF search is not in progress then enters IF loop
            self.search_in_progress = True
            if self.search_marker not in self.marker_list:
                self.map_widget.delete(self.search_marker)

            # getting the location entered in the search bar
            address = self.search_bar.get()
            latitude = geocoder.osm(address).latlng[0]
            longitude = geocoder.osm(address).latlng[1]

            print( "*********   Printing input {} \t latitude and longitude  {} {}".format(address, latitude, longitude ) )
            latlong = str( str(latitude)+ " " +str(longitude) )
            
            self.search_marker = self.map_widget.set_address(
            address , marker=True )
            self.save_marker()

            if self.search_marker is False:
                # address was invalid (return value is False)
                self.search_marker = None
            # self.get_satellite_coordinates()
            self.search_in_progress = False
            return

    def save_marker(self):
        print("\n inside Save_Marker()\n")
        if self.search_marker is not None:
            # print("****** Printing inside Save Marker")
            # print(self.search_marker)
            self.marker_list_box.insert(
                tkinter.END, f" {len(self.marker_list)}. {self.search_marker.text} ")
            self.marker_list_box.see(tkinter.END)
            self.marker_list.append(self.search_marker)
    
        # Function to save the satellite marker into the marker list
    def save_satellite_marker(self, satAddress):
        print("inside Save_satellite_marker() \n")
        self.marker_list.append(satAddress)
        # print("Marker_list value {}".format(self.marker_list))
        if satAddress is not None:
            self.marker_list_box.insert(
                tkinter.END, f" {len(self.marker_list)}. {satAddress} ")
            self.marker_list_box.see(tkinter.END)
            self.marker_list.append(self.search_marker)


    def clear_marker_list(self):
        for marker in self.marker_list:
            self.map_widget.delete(marker)

        self.marker_list_box.delete(0, tkinter.END)
        self.marker_list.clear()
        self.connect_marker()

    def connect_marker(self):
        print("\tInside connect_marker() \n")
        # print("\t\tprinting the marker_List \n {}".format(self.marker_list) )
        position_list = []

        for marker in self.marker_list:
            position_list.append(marker.position)

        if self.marker_path is not None:
            self.map_widget.delete(self.marker_path)

        if len(position_list) > 0:
            print("+++++++ . Printing Connect Marker position List here {}".format(position_list))
            self.marker_path = self.map_widget.set_path(position_list)

    def clear(self):
        self.search_bar.delete(0, last=tkinter.END)
        self.map_widget.delete(self.search_marker)

    def on_closing(self, event=0):
        self.destroy()
        exit()

    def start(self):
        self.mainloop()


 # Function to make HTTP requests 
    def get_satellite_coordinates(self):
        print("Inside get_Satellite_coordinates() \n")
        print( "*********   Printing input latitude and longitude @ Timestamp \n.")
        for i in self.positions:
            print(type(i))
            for j in i.get('positions'):
                # print(j)

            # for i in self.positions.get('positions'):
                latitude = (j.get('satlatitude'))
                longitude =(j.get('satlongitude'))
                timestamp = dt.datetime.fromtimestamp(j.get('timestamp'))
                print("{} {} @ {}".format(latitude, longitude, timestamp ))
                latlong = str( str(latitude)+ " " +str(longitude) )

        # Reverse Geocoding the latitude and longitude before setting the address down below
                locator = Nominatim(user_agent="sample")
                coordinates = tuple( ( latitude, longitude ))
                location = locator.reverse(coordinates)
                print("Satellite is at ")
                print("{} \t {}".format(coordinates, location))
                self.set_satellite_map_marker(latitude, longitude, timestamp)

                satAddress = location

                self.save_satellite_marker(satAddress)
                print("Just got out of save_satellite_marker()")





    # This function is to set markers based on the lat and long for 150 min duration
    def set_satellite_map_marker(self, lat, long, timeStamp):
        
        self.map_widget.set_marker(lat, long, timeStamp)
        return
   
if __name__ == "__main__":
    app = App()
    app.start()
# Out:
# Inside get_Satellite_coordinates()
#
# *********   Printing input latitude and longitude @ Timestamp
# .
# <class 'dict'>
# 37.03138025 64.0880357 @ 2023-07-08 22:51:39
# Satellite is at
# (37.03138025, 64.0880357) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.02811939 64.08561232 @ 2023-07-08 22:51:40
# Satellite is at
# (37.02811939, 64.08561232) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.02485864 64.08318872 @ 2023-07-08 22:51:41
# Satellite is at
# (37.02485864, 64.08318872) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.02159799 64.08076491 @ 2023-07-08 22:51:42
# Satellite is at
# (37.02159799, 64.08076491) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.01833744 64.07834088 @ 2023-07-08 22:51:43
# Satellite is at
# (37.01833744, 64.07834088) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.01507698 64.07591663 @ 2023-07-08 22:51:44
# Satellite is at
# (37.01507698, 64.07591663) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.0118165 64.07349206 @ 2023-07-08 22:51:45
# Satellite is at
# (37.0118165, 64.07349206) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.00855625 64.07106737 @ 2023-07-08 22:51:46
# Satellite is at
# (37.00855625, 64.07106737) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.0052961 64.06864247 @ 2023-07-08 22:51:47
# Satellite is at
# (37.0052961, 64.06864247) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 37.00203606 64.06621734 @ 2023-07-08 22:51:48
# Satellite is at
# (37.00203606, 64.06621734) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.99877611 64.063792 @ 2023-07-08 22:51:49
# Satellite is at
# (36.99877611, 64.063792) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.99551626 64.06136644 @ 2023-07-08 22:51:50
# Satellite is at
# (36.99551626, 64.06136644) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.99225652 64.05894066 @ 2023-07-08 22:51:51
# Satellite is at
# (36.99225652, 64.05894066) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.98899674 64.05651457 @ 2023-07-08 22:51:52
# Satellite is at
# (36.98899674, 64.05651457) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.98573719 64.05408835 @ 2023-07-08 22:51:53
# Satellite is at
# (36.98573719, 64.05408835) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.98247775 64.05166192 @ 2023-07-08 22:51:54
# Satellite is at
# (36.98247775, 64.05166192) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.97921841 64.04923527 @ 2023-07-08 22:51:55
# Satellite is at
# (36.97921841, 64.04923527) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.97595916 64.0468084 @ 2023-07-08 22:51:56
# Satellite is at
# (36.97595916, 64.0468084) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.97270002 64.04438131 @ 2023-07-08 22:51:57
# Satellite is at
# (36.97270002, 64.04438131) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.96944098 64.04195401 @ 2023-07-08 22:51:58
# Satellite is at
# (36.96944098, 64.04195401) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.9661819 64.03952639 @ 2023-07-08 22:51:59
# Satellite is at
# (36.9661819, 64.03952639) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.96292319 64.03709875 @ 2023-07-08 22:52:00
# Satellite is at
# (36.96292319, 64.03709875) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.95966432 64.03467069 @ 2023-07-08 22:52:01
# Satellite is at
# (36.95966432, 64.03467069) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.95640568 64.03224252 @ 2023-07-08 22:52:02
# Satellite is at
# (36.95640568, 64.03224252) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.95314714 64.02981412 @ 2023-07-08 22:52:03
# Satellite is at
# (36.95314714, 64.02981412) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.9498887 64.02738552 @ 2023-07-08 22:52:04
# Satellite is at
# (36.9498887, 64.02738552) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.94663036 64.02495669 @ 2023-07-08 22:52:05
# Satellite is at
# (36.94663036, 64.02495669) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.94337199 64.02252755 @ 2023-07-08 22:52:06
# Satellite is at
# (36.94337199, 64.02252755) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.94011398 64.02009838 @ 2023-07-08 22:52:07
# Satellite is at
# (36.94011398, 64.02009838) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 36.93685582 64.01766881 @ 2023-07-08 22:52:08
# Satellite is at
# (36.93685582, 64.01766881) 	 Halaç etraby, Lebap welaýaty, Türkmenistan
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# <class 'dict'>
# 26.01992085 84.01201045 @ 2023-07-08 22:51:40
# Satellite is at
# (26.01992085, 84.01201045) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 26.01262176 84.01122454 @ 2023-07-08 22:51:41
# Satellite is at
# (26.01262176, 84.01122454) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 26.00532403 84.01043754 @ 2023-07-08 22:51:42
# Satellite is at
# (26.00532403, 84.01043754) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.99802765 84.00964946 @ 2023-07-08 22:51:43
# Satellite is at
# (25.99802765, 84.00964946) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.99073262 84.0088603 @ 2023-07-08 22:51:44
# Satellite is at
# (25.99073262, 84.0088603) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.98343864 84.00807002 @ 2023-07-08 22:51:45
# Satellite is at
# (25.98343864, 84.00807002) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.9761463 84.00727869 @ 2023-07-08 22:51:46
# Satellite is at
# (25.9761463, 84.00727869) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.96885531 84.00648628 @ 2023-07-08 22:51:47
# Satellite is at
# (25.96885531, 84.00648628) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.96156567 84.00569279 @ 2023-07-08 22:51:48
# Satellite is at
# (25.96156567, 84.00569279) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.95427737 84.00489822 @ 2023-07-08 22:51:49
# Satellite is at
# (25.95427737, 84.00489822) 	 Ballia, Uttar Pradesh, 277306, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.94699042 84.00410257 @ 2023-07-08 22:51:50
# Satellite is at
# (25.94699042, 84.00410257) 	 Ballia, Uttar Pradesh, 277306, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.93970481 84.00330585 @ 2023-07-08 22:51:51
# Satellite is at
# (25.93970481, 84.00330585) 	 Ballia, Uttar Pradesh, 277306, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.93242026 84.00250801 @ 2023-07-08 22:51:52
# Satellite is at
# (25.93242026, 84.00250801) 	 Ballia, Uttar Pradesh, 277306, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.92513734 84.00170913 @ 2023-07-08 22:51:53
# Satellite is at
# (25.92513734, 84.00170913) 	 Ballia, Uttar Pradesh, 277306, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.91785576 84.00090917 @ 2023-07-08 22:51:54
# Satellite is at
# (25.91785576, 84.00090917) 	 Sikanderpur, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.91057554 84.00010813 @ 2023-07-08 22:51:55
# Satellite is at
# (25.91057554, 84.00010813) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.90329665 83.99930602 @ 2023-07-08 22:51:56
# Satellite is at
# (25.90329665, 83.99930602) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.89601911 83.99850284 @ 2023-07-08 22:51:57
# Satellite is at
# (25.89601911, 83.99850284) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.8887429 83.99769858 @ 2023-07-08 22:51:58
# Satellite is at
# (25.8887429, 83.99769858) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.88146775 83.99689321 @ 2023-07-08 22:51:59
# Satellite is at
# (25.88146775, 83.99689321) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.87419453 83.99608684 @ 2023-07-08 22:52:00
# Satellite is at
# (25.87419453, 83.99608684) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.86692206 83.99527933 @ 2023-07-08 22:52:01
# Satellite is at
# (25.86692206, 83.99527933) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.85965122 83.99447079 @ 2023-07-08 22:52:02
# Satellite is at
# (25.85965122, 83.99447079) 	 Government Hospital Kureji, MDR150E, Ballia, Uttar Pradesh, 277121, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.85238172 83.99366117 @ 2023-07-08 22:52:03
# Satellite is at
# (25.85238172, 83.99366117) 	 MDR150E, Rasra, Ballia, Uttar Pradesh, 221711, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.84511356 83.99285048 @ 2023-07-08 22:52:04
# Satellite is at
# (25.84511356, 83.99285048) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.83784675 83.99203872 @ 2023-07-08 22:52:05
# Satellite is at
# (25.83784675, 83.99203872) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.83058098 83.99122586 @ 2023-07-08 22:52:06
# Satellite is at
# (25.83058098, 83.99122586) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.82331713 83.990412 @ 2023-07-08 22:52:07
# Satellite is at
# (25.82331713, 83.990412) 	 Rasra, Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.81605403 83.98959701 @ 2023-07-08 22:52:08
# Satellite is at
# (25.81605403, 83.98959701) 	 Ballia, Uttar Pradesh, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 25.80879256 83.98878098 @ 2023-07-08 22:52:09
# Satellite is at
# (25.80879256, 83.98878098) 	 NH128B, Fefana, Ballia, Uttar Pradesh, 277503, India
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()

# %%
# print(type(above_satellite_request))
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
