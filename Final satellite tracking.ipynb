# %% [markdown]
# ### All import statements exists here

# %%
import geocoder
import sys
import tkinter
import tkinter.messagebox
from tkintermapview import TkinterMapView
import geocoder
from geopy.geocoders import Nominatim
import datetime as dt
import requests
import json
import pprint

# %% [markdown]
# ## Find the Satellites that are above our head

# %%
# geocoder.ip('me') is used to get current location in latitude and longitude
locPlaceHldr = geocoder.ip('me')
location = locPlaceHldr.latlng
print(" The Current Location is: {}".format(location))
# print("{}, {}".format(location[0], location[1]))



url_str = "http://api.n2yo.com/rest/v1/satellite/above/"

# USing the below line for manual testing only
# latitude, longitude = "44.2367", "66.3287"

latitude, longitude = str(location[0]), str(location[1])

# This below value 25 would provide a search radius of 466 km
#      at altitude of 1000km from observer's posn
leading_url = "0/25/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7"
final_url = url_str+latitude+"/"+longitude+"/"+leading_url
print(url_str+latitude+"/"+longitude+"/"+leading_url)

above_satellite_request = requests.get(final_url)
print(above_satellite_request.json())

## This Code is WORKING
# Out:
#  The Current Location is: [32.7353, 74.8617]
# http://api.n2yo.com/rest/v1/satellite/above/32.7353/74.8617/0/25/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
# {'info': {'category': 'Military', 'transactionscount': 5, 'satcount': 2}, 'above': [{'satid': 15226, 'satname': 'USA 4', 'intDesignator': '1984-091A', 'launchDate': '1984-08-28', 'satlat': 31.5806, 'satlng': 68.507, 'satalt': 24258.6596}, {'satid': 40296, 'satname': 'MERIDIAN 7', 'intDesignator': '2014-069A', 'launchDate': '2014-10-30', 'satlat': 22.9056, 'satlng': 75.5545, 'satalt': 11424.2115}]}

# %% [markdown]
# ## Retreiving the positions of the satl mentioned above

# %%
gps_position_data = above_satellite_request.json()

# {
#     "info":{
#        "category":"Military",
#        "transactionscount":5,
#        "satcount":4
#     },
#     "above":[
#        {
#           "satid":7625,
#           "satname":"COSMOS 706",
#           "intDesignator":"1975-007A",
#           "launchDate":"1975-01-30",
#           "satlat":41.1165,
#           "satlng":87.9811,
#           "satalt":19517.9732
#        },
#        {
#           "satid":13636,
#           "satname":"DSCS 2-15",
#           "intDesignator":"1982-106A",
#           "launchDate":"1982-10-30",
#           "satlat":13.0852,
#           "satlng":69.2573,
#           "satalt":37296.7288
#        },
#        {
#           "satid":28095,
#           "satname":"USA 173",
#           "intDesignator":"2003-054A",
#           "launchDate":"2003-12-02",
#           "satlat":31.4633,
#           "satlng":72.2249,
#           "satalt":1390.3571
#        },
#        {
#           "satid":37398,
#           "satname":"MERIDIAN 4",
#           "intDesignator":"2011-018A",
#           "launchDate":"2011-05-04",
#           "satlat":35.2406,
#           "satlng":64.4581,
#           "satalt":12504.3492
#        }
#     ]
#  }

# print(gps_position_data.keys())

print("There are {} Military Satellites on top of your head. ".format(gps_position_data.get("info")['satcount'])) # THis returns the count of military satellites

url_str = "http://api.n2yo.com/rest/v1/satellite/positions/"
latitude = str(33.496552592013906)
longitude = str(76.52195669878829)
leading_url = "10/60/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7"

print("\n Satellites are revolving on top of india: ")
for i in gps_position_data['above']:
    print("\n {} ".format(i.get('satid')) )
      
for i in gps_position_data['above']:
    sat_id = str(i.get('satid'))
    final_url = url_str+sat_id+"/"+latitude+"/"+longitude+"/"+leading_url
    print(final_url+"\n")
    r = requests.get(final_url)
    pprint.pprint(r.json())
    print("\n")
# Out:
# There are 2 Military Satellites on top of your head.
#
#  Satellites are revolving on top of india:
#
#  15226
#
#  40296
# http://api.n2yo.com/rest/v1/satellite/positions/15226/33.496552592013906/76.52195669878829/10/60/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
#
# {'info': {'satid': 15226, 'satname': 'USA 4', 'transactionscount': 7},
#  'positions': [{'azimuth': 251.44,
#                 'dec': 29.94586742,
#                 'eclipsed': False,
#                 'elevation': 80.59,
#                 'ra': 352.09684504,
#                 'sataltitude': 23877.45,
#                 'satlatitude': 30.85434666,
#                 'satlongitude': 68.30480096,
#                 'timestamp': 1682398376},
#                {'azimuth': 251.42,
#                 'dec': 29.94054976,
#                 'eclipsed': False,
#                 'elevation': 80.58,
#                 'ra': 352.09950898,
#                 'sataltitude': 23875.28,
#                 'satlatitude': 30.85020866,
#                 'satlongitude': 68.30365658,
#                 'timestamp': 1682398377},
#                {'azimuth': 251.39,
#                 'dec': 29.93523107,
#                 'eclipsed': False,
#                 'elevation': 80.58,
#                 'ra': 352.10217308,
#                 'sataltitude': 23873.12,
#                 'satlatitude': 30.84606998,
#                 'satlongitude': 68.30251239,
#                 'timestamp': 1682398378},
#                {'azimuth': 251.36,
#                 'dec': 29.92991133,
#                 'eclipsed': False,
#                 'elevation': 80.58,
#                 'ra': 352.10483734,
#                 'sataltitude': 23870.96,
#                 'satlatitude': 30.84193065,
#                 'satlongitude': 68.30136836,
#                 'timestamp': 1682398379},
#                {'azimuth': 251.34,
#                 'dec': 29.92459056,
#                 'eclipsed': False,
#                 'elevation': 80.57,
#                 'ra': 352.10750177,
#                 'sataltitude': 23868.8,
#                 'satlatitude': 30.83779065,
#                 'satlongitude': 68.3002245,
#                 'timestamp': 1682398380},
#                {'azimuth': 251.31,
#                 'dec': 29.91926874,
#                 'eclipsed': False,
#                 'elevation': 80.57,
#                 'ra': 352.11016635,
#                 'sataltitude': 23866.64,
#                 'satlatitude': 30.83364999,
#                 'satlongitude': 68.29908082,
#                 'timestamp': 1682398381},
#                {'azimuth': 251.29,
#                 'dec': 29.91394588,
#                 'eclipsed': False,
#                 'elevation': 80.57,
#                 'ra': 352.1128311,
#                 'sataltitude': 23864.48,
#                 'satlatitude': 30.82950867,
#                 'satlongitude': 68.29793731,
#                 'timestamp': 1682398382},
#                {'azimuth': 251.26,
#                 'dec': 29.90862176,
#                 'eclipsed': False,
#                 'elevation': 80.56,
#                 'ra': 352.11549611,
#                 'sataltitude': 23862.31,
#                 'satlatitude': 30.82536652,
#                 'satlongitude': 68.29679392,
#                 'timestamp': 1682398383},
#                {'azimuth': 251.23,
#                 'dec': 29.90329704,
#                 'eclipsed': False,
#                 'elevation': 80.56,
#                 'ra': 352.11816108,
#                 'sataltitude': 23860.15,
#                 'satlatitude': 30.82122403,
#                 'satlongitude': 68.2956508,
#                 'timestamp': 1682398384},
#                {'azimuth': 251.21,
#                 'dec': 29.89797084,
#                 'eclipsed': False,
#                 'elevation': 80.56,
#                 'ra': 352.12082642,
#                 'sataltitude': 23857.99,
#                 'satlatitude': 30.81708055,
#                 'satlongitude': 68.29450776,
#                 'timestamp': 1682398385},
#                {'azimuth': 251.18,
#                 'dec': 29.89264381,
#                 'eclipsed': False,
#                 'elevation': 80.55,
#                 'ra': 352.12349182,
#                 'sataltitude': 23855.83,
#                 'satlatitude': 30.81293657,
#                 'satlongitude': 68.29336494,
#                 'timestamp': 1682398386},
#                {'azimuth': 251.15,
#                 'dec': 29.88731574,
#                 'eclipsed': False,
#                 'elevation': 80.55,
#                 'ra': 352.12615737,
#                 'sataltitude': 23853.66,
#                 'satlatitude': 30.80879193,
#                 'satlongitude': 68.29222229,
#                 'timestamp': 1682398387},
#                {'azimuth': 251.13,
#                 'dec': 29.88198662,
#                 'eclipsed': False,
#                 'elevation': 80.55,
#                 'ra': 352.1288231,
#                 'sataltitude': 23851.5,
#                 'satlatitude': 30.80464662,
#                 'satlongitude': 68.29107981,
#                 'timestamp': 1682398388},
#                {'azimuth': 251.1,
#                 'dec': 29.87665646,
#                 'eclipsed': False,
#                 'elevation': 80.54,
#                 'ra': 352.13148898,
#                 'sataltitude': 23849.34,
#                 'satlatitude': 30.80050064,
#                 'satlongitude': 68.28993751,
#                 'timestamp': 1682398389},
#                {'azimuth': 251.07,
#                 'dec': 29.87132505,
#                 'eclipsed': False,
#                 'elevation': 80.54,
#                 'ra': 352.13415513,
#                 'sataltitude': 23847.17,
#                 'satlatitude': 30.79635384,
#                 'satlongitude': 68.28879534,
#                 'timestamp': 1682398390},
#                {'azimuth': 251.05,
#                 'dec': 29.86599301,
#                 'eclipsed': False,
#                 'elevation': 80.54,
#                 'ra': 352.13682123,
#                 'sataltitude': 23845.01,
#                 'satlatitude': 30.7922067,
#                 'satlongitude': 68.28765342,
#                 'timestamp': 1682398391},
#                {'azimuth': 251.02,
#                 'dec': 29.8606595,
#                 'eclipsed': False,
#                 'elevation': 80.53,
#                 'ra': 352.13948771,
#                 'sataltitude': 23842.85,
#                 'satlatitude': 30.78805857,
#                 'satlongitude': 68.28651159,
#                 'timestamp': 1682398392},
#                {'azimuth': 251,
#                 'dec': 29.85532517,
#                 'eclipsed': False,
#                 'elevation': 80.53,
#                 'ra': 352.14215425,
#                 'sataltitude': 23840.68,
#                 'satlatitude': 30.78390993,
#                 'satlongitude': 68.28536998,
#                 'timestamp': 1682398393},
#                {'azimuth': 250.97,
#                 'dec': 29.84998978,
#                 'eclipsed': False,
#                 'elevation': 80.53,
#                 'ra': 352.14482095,
#                 'sataltitude': 23838.52,
#                 'satlatitude': 30.77976063,
#                 'satlongitude': 68.28422855,
#                 'timestamp': 1682398394},
#                {'azimuth': 250.94,
#                 'dec': 29.84465335,
#                 'eclipsed': False,
#                 'elevation': 80.52,
#                 'ra': 352.14748781,
#                 'sataltitude': 23836.35,
#                 'satlatitude': 30.77561067,
#                 'satlongitude': 68.28308728,
#                 'timestamp': 1682398395},
#                {'azimuth': 250.92,
#                 'dec': 29.83931588,
#                 'eclipsed': False,
#                 'elevation': 80.52,
#                 'ra': 352.15015483,
#                 'sataltitude': 23834.19,
#                 'satlatitude': 30.77146003,
#                 'satlongitude': 68.28194619,
#                 'timestamp': 1682398396},
#                {'azimuth': 250.89,
#                 'dec': 29.83397735,
#                 'eclipsed': False,
#                 'elevation': 80.52,
#                 'ra': 352.15282202,
#                 'sataltitude': 23832.02,
#                 'satlatitude': 30.76730873,
#                 'satlongitude': 68.28080527,
#                 'timestamp': 1682398397},
#                {'azimuth': 250.86,
#                 'dec': 29.82863778,
#                 'eclipsed': False,
#                 'elevation': 80.51,
#                 'ra': 352.15548937,
#                 'sataltitude': 23829.86,
#                 'satlatitude': 30.76315677,
#                 'satlongitude': 68.27966453,
#                 'timestamp': 1682398398},
#                {'azimuth': 250.84,
#                 'dec': 29.82329695,
#                 'eclipsed': False,
#                 'elevation': 80.51,
#                 'ra': 352.15815699,
#                 'sataltitude': 23827.69,
#                 'satlatitude': 30.75900397,
#                 'satlongitude': 68.27852391,
#                 'timestamp': 1682398399},
#                {'azimuth': 250.81,
#                 'dec': 29.81795528,
#                 'eclipsed': False,
#                 'elevation': 80.5,
#                 'ra': 352.16082467,
#                 'sataltitude': 23825.53,
#                 'satlatitude': 30.75485067,
#                 'satlongitude': 68.27738352,
#                 'timestamp': 1682398400},
#                {'azimuth': 250.79,
#                 'dec': 29.81261257,
#                 'eclipsed': False,
#                 'elevation': 80.5,
#                 'ra': 352.16349251,
#                 'sataltitude': 23823.36,
#                 'satlatitude': 30.7506967,
#                 'satlongitude': 68.2762433,
#                 'timestamp': 1682398401},
#                {'azimuth': 250.76,
#                 'dec': 29.80726881,
#                 'eclipsed': False,
#                 'elevation': 80.5,
#                 'ra': 352.16616051,
#                 'sataltitude': 23821.19,
#                 'satlatitude': 30.74654207,
#                 'satlongitude': 68.27510325,
#                 'timestamp': 1682398402},
#                {'azimuth': 250.73,
#                 'dec': 29.801924,
#                 'eclipsed': False,
#                 'elevation': 80.49,
#                 'ra': 352.16882868,
#                 'sataltitude': 23819.03,
#                 'satlatitude': 30.74238677,
#                 'satlongitude': 68.27396337,
#                 'timestamp': 1682398403},
#                {'azimuth': 250.71,
#                 'dec': 29.79657813,
#                 'eclipsed': False,
#                 'elevation': 80.49,
#                 'ra': 352.17149701,
#                 'sataltitude': 23816.86,
#                 'satlatitude': 30.7382308,
#                 'satlongitude': 68.27282367,
#                 'timestamp': 1682398404},
#                {'azimuth': 250.68,
#                 'dec': 29.79123122,
#                 'eclipsed': False,
#                 'elevation': 80.49,
#                 'ra': 352.17416551,
#                 'sataltitude': 23814.69,
#                 'satlatitude': 30.73407416,
#                 'satlongitude': 68.27168415,
#                 'timestamp': 1682398405},
#                {'azimuth': 250.66,
#                 'dec': 29.78588305,
#                 'eclipsed': False,
#                 'elevation': 80.48,
#                 'ra': 352.17683427,
#                 'sataltitude': 23812.53,
#                 'satlatitude': 30.72991669,
#                 'satlongitude': 68.27054475,
#                 'timestamp': 1682398406},
#                {'azimuth': 250.63,
#                 'dec': 29.78053404,
#                 'eclipsed': False,
#                 'elevation': 80.48,
#                 'ra': 352.1795031,
#                 'sataltitude': 23810.36,
#                 'satlatitude': 30.72575871,
#                 'satlongitude': 68.26940557,
#                 'timestamp': 1682398407},
#                {'azimuth': 250.6,
#                 'dec': 29.77518397,
#                 'eclipsed': False,
#                 'elevation': 80.48,
#                 'ra': 352.18217209,
#                 'sataltitude': 23808.19,
#                 'satlatitude': 30.72160007,
#                 'satlongitude': 68.26826657,
#                 'timestamp': 1682398408},
#                {'azimuth': 250.58,
#                 'dec': 29.76983286,
#                 'eclipsed': False,
#                 'elevation': 80.47,
#                 'ra': 352.18484124,
#                 'sataltitude': 23806.02,
#                 'satlatitude': 30.71744076,
#                 'satlongitude': 68.26712774,
#                 'timestamp': 1682398409},
#                {'azimuth': 250.55,
#                 'dec': 29.76448069,
#                 'eclipsed': False,
#                 'elevation': 80.47,
#                 'ra': 352.18751055,
#                 'sataltitude': 23803.86,
#                 'satlatitude': 30.71328078,
#                 'satlongitude': 68.26598909,
#                 'timestamp': 1682398410},
#                {'azimuth': 250.53,
#                 'dec': 29.75912748,
#                 'eclipsed': False,
#                 'elevation': 80.47,
#                 'ra': 352.19018004,
#                 'sataltitude': 23801.69,
#                 'satlatitude': 30.70912012,
#                 'satlongitude': 68.26485061,
#                 'timestamp': 1682398411},
#                {'azimuth': 250.5,
#                 'dec': 29.75377321,
#                 'eclipsed': False,
#                 'elevation': 80.46,
#                 'ra': 352.19284968,
#                 'sataltitude': 23799.52,
#                 'satlatitude': 30.70495881,
#                 'satlongitude': 68.26371231,
#                 'timestamp': 1682398412},
#                {'azimuth': 250.47,
#                 'dec': 29.74841767,
#                 'eclipsed': False,
#                 'elevation': 80.46,
#                 'ra': 352.1955196,
#                 'sataltitude': 23797.35,
#                 'satlatitude': 30.70079665,
#                 'satlongitude': 68.26257413,
#                 'timestamp': 1682398413},
#                {'azimuth': 250.45,
#                 'dec': 29.74306129,
#                 'eclipsed': False,
#                 'elevation': 80.46,
#                 'ra': 352.19818957,
#                 'sataltitude': 23795.18,
#                 'satlatitude': 30.69663399,
#                 'satlongitude': 68.26143618,
#                 'timestamp': 1682398414},
#                {'azimuth': 250.42,
#                 'dec': 29.73770386,
#                 'eclipsed': False,
#                 'elevation': 80.45,
#                 'ra': 352.20085971,
#                 'sataltitude': 23793.01,
#                 'satlatitude': 30.69247066,
#                 'satlongitude': 68.2602984,
#                 'timestamp': 1682398415},
#                {'azimuth': 250.4,
#                 'dec': 29.73234538,
#                 'eclipsed': False,
#                 'elevation': 80.45,
#                 'ra': 352.20353002,
#                 'sataltitude': 23790.84,
#                 'satlatitude': 30.68830666,
#                 'satlongitude': 68.2591608,
#                 'timestamp': 1682398416},
#                {'azimuth': 250.37,
#                 'dec': 29.72698584,
#                 'eclipsed': False,
#                 'elevation': 80.45,
#                 'ra': 352.20620049,
#                 'sataltitude': 23788.67,
#                 'satlatitude': 30.68414199,
#                 'satlongitude': 68.25802337,
#                 'timestamp': 1682398417},
#                {'azimuth': 250.34,
#                 'dec': 29.72162525,
#                 'eclipsed': False,
#                 'elevation': 80.44,
#                 'ra': 352.20887112,
#                 'sataltitude': 23786.5,
#                 'satlatitude': 30.67997665,
#                 'satlongitude': 68.25688612,
#                 'timestamp': 1682398418},
#                {'azimuth': 250.32,
#                 'dec': 29.71626361,
#                 'eclipsed': False,
#                 'elevation': 80.44,
#                 'ra': 352.21154192,
#                 'sataltitude': 23784.33,
#                 'satlatitude': 30.67581064,
#                 'satlongitude': 68.25574904,
#                 'timestamp': 1682398419},
#                {'azimuth': 250.29,
#                 'dec': 29.71090069,
#                 'eclipsed': False,
#                 'elevation': 80.44,
#                 'ra': 352.21421299,
#                 'sataltitude': 23782.16,
#                 'satlatitude': 30.67164379,
#                 'satlongitude': 68.25461209,
#                 'timestamp': 1682398420},
#                {'azimuth': 250.27,
#                 'dec': 29.70553715,
#                 'eclipsed': False,
#                 'elevation': 80.43,
#                 'ra': 352.21688401,
#                 'sataltitude': 23779.99,
#                 'satlatitude': 30.6674766,
#                 'satlongitude': 68.25347541,
#                 'timestamp': 1682398421},
#                {'azimuth': 250.24,
#                 'dec': 29.70017212,
#                 'eclipsed': False,
#                 'elevation': 80.43,
#                 'ra': 352.21955542,
#                 'sataltitude': 23777.82,
#                 'satlatitude': 30.66330841,
#                 'satlongitude': 68.25233881,
#                 'timestamp': 1682398422},
#                {'azimuth': 250.21,
#                 'dec': 29.69480625,
#                 'eclipsed': False,
#                 'elevation': 80.43,
#                 'ra': 352.22222688,
#                 'sataltitude': 23775.65,
#                 'satlatitude': 30.65913971,
#                 'satlongitude': 68.25120244,
#                 'timestamp': 1682398423},
#                {'azimuth': 250.19,
#                 'dec': 29.68943932,
#                 'eclipsed': False,
#                 'elevation': 80.42,
#                 'ra': 352.2248985,
#                 'sataltitude': 23773.48,
#                 'satlatitude': 30.65497035,
#                 'satlongitude': 68.25006624,
#                 'timestamp': 1682398424},
#                {'azimuth': 250.16,
#                 'dec': 29.68407134,
#                 'eclipsed': False,
#                 'elevation': 80.42,
#                 'ra': 352.22757029,
#                 'sataltitude': 23771.31,
#                 'satlatitude': 30.6508003,
#                 'satlongitude': 68.24893022,
#                 'timestamp': 1682398425},
#                {'azimuth': 250.14,
#                 'dec': 29.67870229,
#                 'eclipsed': False,
#                 'elevation': 80.42,
#                 'ra': 352.23024225,
#                 'sataltitude': 23769.14,
#                 'satlatitude': 30.64662959,
#                 'satlongitude': 68.24779437,
#                 'timestamp': 1682398426},
#                {'azimuth': 250.11,
#                 'dec': 29.67333198,
#                 'eclipsed': False,
#                 'elevation': 80.41,
#                 'ra': 352.23291448,
#                 'sataltitude': 23766.97,
#                 'satlatitude': 30.64245804,
#                 'satlongitude': 68.24665865,
#                 'timestamp': 1682398427},
#                {'azimuth': 250.09,
#                 'dec': 29.66796104,
#                 'eclipsed': False,
#                 'elevation': 80.41,
#                 'ra': 352.23558666,
#                 'sataltitude': 23764.8,
#                 'satlatitude': 30.63828615,
#                 'satlongitude': 68.24552321,
#                 'timestamp': 1682398428},
#                {'azimuth': 250.06,
#                 'dec': 29.6625886,
#                 'eclipsed': False,
#                 'elevation': 80.4,
#                 'ra': 352.23825922,
#                 'sataltitude': 23762.62,
#                 'satlatitude': 30.63411325,
#                 'satlongitude': 68.24438784,
#                 'timestamp': 1682398429},
#                {'azimuth': 250.03,
#                 'dec': 29.65721533,
#                 'eclipsed': False,
#                 'elevation': 80.4,
#                 'ra': 352.24093185,
#                 'sataltitude': 23760.45,
#                 'satlatitude': 30.62993985,
#                 'satlongitude': 68.2432527,
#                 'timestamp': 1682398430},
#                {'azimuth': 250.01,
#                 'dec': 29.65184099,
#                 'eclipsed': False,
#                 'elevation': 80.4,
#                 'ra': 352.24360463,
#                 'sataltitude': 23758.28,
#                 'satlatitude': 30.62576577,
#                 'satlongitude': 68.24211773,
#                 'timestamp': 1682398431},
#                {'azimuth': 249.98,
#                 'dec': 29.6464656,
#                 'eclipsed': False,
#                 'elevation': 80.39,
#                 'ra': 352.24627758,
#                 'sataltitude': 23756.11,
#                 'satlatitude': 30.62159102,
#                 'satlongitude': 68.24098294,
#                 'timestamp': 1682398432},
#                {'azimuth': 249.96,
#                 'dec': 29.64108914,
#                 'eclipsed': False,
#                 'elevation': 80.39,
#                 'ra': 352.2489507,
#                 'sataltitude': 23753.93,
#                 'satlatitude': 30.61741559,
#                 'satlongitude': 68.23984833,
#                 'timestamp': 1682398433},
#                {'azimuth': 249.93,
#                 'dec': 29.63571163,
#                 'eclipsed': False,
#                 'elevation': 80.39,
#                 'ra': 352.25162399,
#                 'sataltitude': 23751.76,
#                 'satlatitude': 30.61323949,
#                 'satlongitude': 68.2387139,
#                 'timestamp': 1682398434},
#                {'azimuth': 249.91,
#                 'dec': 29.63033305,
#                 'eclipsed': False,
#                 'elevation': 80.38,
#                 'ra': 352.25429744,
#                 'sataltitude': 23749.59,
#                 'satlatitude': 30.60906272,
#                 'satlongitude': 68.23757964,
#                 'timestamp': 1682398435}]}
#
#
# http://api.n2yo.com/rest/v1/satellite/positions/40296/33.496552592013906/76.52195669878829/10/60/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
#
# {'info': {'satid': 40296, 'satname': 'MERIDIAN 7', 'transactionscount': 8},
#  'positions': [{'azimuth': 183.09,
#                 'dec': 20.29716345,
#                 'eclipsed': False,
#                 'elevation': 76.93,
#                 'ra': 1.67320022,
#                 'sataltitude': 12084.69,
#                 'satlatitude': 24.90652593,
#                 'satlongitude': 76.0141504,
#                 'timestamp': 1682398380},
#                {'azimuth': 183.08,
#                 'dec': 20.31442644,
#                 'eclipsed': False,
#                 'elevation': 76.95,
#                 'ra': 1.68087815,
#                 'sataltitude': 12088.29,
#                 'satlatitude': 24.91709889,
#                 'satlongitude': 76.01651564,
#                 'timestamp': 1682398381},
#                {'azimuth': 183.06,
#                 'dec': 20.33167923,
#                 'eclipsed': False,
#                 'elevation': 76.97,
#                 'ra': 1.68855359,
#                 'sataltitude': 12091.89,
#                 'satlatitude': 24.92766742,
#                 'satlongitude': 76.01887945,
#                 'timestamp': 1682398382},
#                {'azimuth': 183.05,
#                 'dec': 20.34892251,
#                 'eclipsed': False,
#                 'elevation': 76.98,
#                 'ra': 1.69622685,
#                 'sataltitude': 12095.48,
#                 'satlatitude': 24.93823198,
#                 'satlongitude': 76.02124193,
#                 'timestamp': 1682398383},
#                {'azimuth': 183.04,
#                 'dec': 20.36615423,
#                 'eclipsed': False,
#                 'elevation': 77,
#                 'ra': 1.70389701,
#                 'sataltitude': 12099.08,
#                 'satlatitude': 24.94879127,
#                 'satlongitude': 76.02360279,
#                 'timestamp': 1682398384},
#                {'azimuth': 183.03,
#                 'dec': 20.38337715,
#                 'eclipsed': False,
#                 'elevation': 77.02,
#                 'ra': 1.71156531,
#                 'sataltitude': 12102.68,
#                 'satlatitude': 24.95934701,
#                 'satlongitude': 76.02596242,
#                 'timestamp': 1682398385},
#                {'azimuth': 183.02,
#                 'dec': 20.40058922,
#                 'eclipsed': False,
#                 'elevation': 77.04,
#                 'ra': 1.71923082,
#                 'sataltitude': 12106.27,
#                 'satlatitude': 24.96989792,
#                 'satlongitude': 76.02832052,
#                 'timestamp': 1682398386},
#                {'azimuth': 183.01,
#                 'dec': 20.41779112,
#                 'eclipsed': False,
#                 'elevation': 77.05,
#                 'ra': 1.72689385,
#                 'sataltitude': 12109.87,
#                 'satlatitude': 24.98044443,
#                 'satlongitude': 76.0306772,
#                 'timestamp': 1682398387},
#                {'azimuth': 183,
#                 'dec': 20.43498287,
#                 'eclipsed': False,
#                 'elevation': 77.07,
#                 'ra': 1.73455441,
#                 'sataltitude': 12113.46,
#                 'satlatitude': 24.99098655,
#                 'satlongitude': 76.03303246,
#                 'timestamp': 1682398388},
#                {'azimuth': 182.99,
#                 'dec': 20.45216448,
#                 'eclipsed': False,
#                 'elevation': 77.09,
#                 'ra': 1.74221249,
#                 'sataltitude': 12117.06,
#                 'satlatitude': 25.00152427,
#                 'satlongitude': 76.03538629,
#                 'timestamp': 1682398389},
#                {'azimuth': 182.98,
#                 'dec': 20.46933665,
#                 'eclipsed': False,
#                 'elevation': 77.1,
#                 'ra': 1.74986842,
#                 'sataltitude': 12120.65,
#                 'satlatitude': 25.01205803,
#                 'satlongitude': 76.0377388,
#                 'timestamp': 1682398390},
#                {'azimuth': 182.97,
#                 'dec': 20.48649731,
#                 'eclipsed': False,
#                 'elevation': 77.12,
#                 'ra': 1.75752125,
#                 'sataltitude': 12124.25,
#                 'satlatitude': 25.02258654,
#                 'satlongitude': 76.0400897,
#                 'timestamp': 1682398391},
#                {'azimuth': 182.95,
#                 'dec': 20.50364924,
#                 'eclipsed': False,
#                 'elevation': 77.14,
#                 'ra': 1.76517224,
#                 'sataltitude': 12127.84,
#                 'satlatitude': 25.03311153,
#                 'satlongitude': 76.04243937,
#                 'timestamp': 1682398392},
#                {'azimuth': 182.94,
#                 'dec': 20.52079036,
#                 'eclipsed': False,
#                 'elevation': 77.16,
#                 'ra': 1.77282046,
#                 'sataltitude': 12131.43,
#                 'satlatitude': 25.0436317,
#                 'satlongitude': 76.04478752,
#                 'timestamp': 1682398393},
#                {'azimuth': 182.93,
#                 'dec': 20.53792139,
#                 'eclipsed': False,
#                 'elevation': 77.17,
#                 'ra': 1.78046622,
#                 'sataltitude': 12135.03,
#                 'satlatitude': 25.0541475,
#                 'satlongitude': 76.04713426,
#                 'timestamp': 1682398394},
#                {'azimuth': 182.92,
#                 'dec': 20.55504232,
#                 'eclipsed': False,
#                 'elevation': 77.19,
#                 'ra': 1.78810952,
#                 'sataltitude': 12138.62,
#                 'satlatitude': 25.06465892,
#                 'satlongitude': 76.04947959,
#                 'timestamp': 1682398395},
#                {'azimuth': 182.91,
#                 'dec': 20.57215317,
#                 'eclipsed': False,
#                 'elevation': 77.21,
#                 'ra': 1.79575037,
#                 'sataltitude': 12142.21,
#                 'satlatitude': 25.07516597,
#                 'satlongitude': 76.0518235,
#                 'timestamp': 1682398396},
#                {'azimuth': 182.9,
#                 'dec': 20.58925395,
#                 'eclipsed': False,
#                 'elevation': 77.23,
#                 'ra': 1.80338876,
#                 'sataltitude': 12145.8,
#                 'satlatitude': 25.08566865,
#                 'satlongitude': 76.054166,
#                 'timestamp': 1682398397},
#                {'azimuth': 182.89,
#                 'dec': 20.60634466,
#                 'eclipsed': False,
#                 'elevation': 77.24,
#                 'ra': 1.8110247,
#                 'sataltitude': 12149.4,
#                 'satlatitude': 25.09616696,
#                 'satlongitude': 76.05650708,
#                 'timestamp': 1682398398},
#                {'azimuth': 182.88,
#                 'dec': 20.623426,
#                 'eclipsed': False,
#                 'elevation': 77.26,
#                 'ra': 1.8186585,
#                 'sataltitude': 12152.99,
#                 'satlatitude': 25.10666133,
#                 'satlongitude': 76.05884685,
#                 'timestamp': 1682398399},
#                {'azimuth': 182.87,
#                 'dec': 20.6404966,
#                 'eclipsed': False,
#                 'elevation': 77.28,
#                 'ra': 1.82628955,
#                 'sataltitude': 12156.58,
#                 'satlatitude': 25.11715092,
#                 'satlongitude': 76.06118512,
#                 'timestamp': 1682398400},
#                {'azimuth': 182.85,
#                 'dec': 20.65755716,
#                 'eclipsed': False,
#                 'elevation': 77.29,
#                 'ra': 1.83391815,
#                 'sataltitude': 12160.17,
#                 'satlatitude': 25.12763614,
#                 'satlongitude': 76.06352197,
#                 'timestamp': 1682398401},
#                {'azimuth': 182.84,
#                 'dec': 20.67460769,
#                 'eclipsed': False,
#                 'elevation': 77.31,
#                 'ra': 1.84154432,
#                 'sataltitude': 12163.76,
#                 'satlatitude': 25.13811701,
#                 'satlongitude': 76.06585742,
#                 'timestamp': 1682398402},
#                {'azimuth': 182.83,
#                 'dec': 20.69164819,
#                 'eclipsed': False,
#                 'elevation': 77.33,
#                 'ra': 1.84916804,
#                 'sataltitude': 12167.35,
#                 'satlatitude': 25.14859353,
#                 'satlongitude': 76.06819146,
#                 'timestamp': 1682398403},
#                {'azimuth': 182.82,
#                 'dec': 20.70867868,
#                 'eclipsed': False,
#                 'elevation': 77.35,
#                 'ra': 1.85678932,
#                 'sataltitude': 12170.94,
#                 'satlatitude': 25.1590657,
#                 'satlongitude': 76.0705241,
#                 'timestamp': 1682398404},
#                {'azimuth': 182.81,
#                 'dec': 20.72569916,
#                 'eclipsed': False,
#                 'elevation': 77.36,
#                 'ra': 1.86440818,
#                 'sataltitude': 12174.53,
#                 'satlatitude': 25.16953352,
#                 'satlongitude': 76.07285533,
#                 'timestamp': 1682398405},
#                {'azimuth': 182.8,
#                 'dec': 20.74271032,
#                 'eclipsed': False,
#                 'elevation': 77.38,
#                 'ra': 1.8720249,
#                 'sataltitude': 12178.12,
#                 'satlatitude': 25.17999742,
#                 'satlongitude': 76.07518525,
#                 'timestamp': 1682398406},
#                {'azimuth': 182.79,
#                 'dec': 20.75971081,
#                 'eclipsed': False,
#                 'elevation': 77.4,
#                 'ra': 1.87963889,
#                 'sataltitude': 12181.71,
#                 'satlatitude': 25.19045656,
#                 'satlongitude': 76.07751368,
#                 'timestamp': 1682398407},
#                {'azimuth': 182.78,
#                 'dec': 20.77670132,
#                 'eclipsed': False,
#                 'elevation': 77.41,
#                 'ra': 1.88725046,
#                 'sataltitude': 12185.3,
#                 'satlatitude': 25.20091136,
#                 'satlongitude': 76.0798407,
#                 'timestamp': 1682398408},
#                {'azimuth': 182.76,
#                 'dec': 20.79368185,
#                 'eclipsed': False,
#                 'elevation': 77.43,
#                 'ra': 1.89485959,
#                 'sataltitude': 12188.88,
#                 'satlatitude': 25.21136182,
#                 'satlongitude': 76.08216633,
#                 'timestamp': 1682398409},
#                {'azimuth': 182.75,
#                 'dec': 20.81065242,
#                 'eclipsed': False,
#                 'elevation': 77.45,
#                 'ra': 1.90246631,
#                 'sataltitude': 12192.47,
#                 'satlatitude': 25.22180795,
#                 'satlongitude': 76.08449055,
#                 'timestamp': 1682398410},
#                {'azimuth': 182.74,
#                 'dec': 20.82761303,
#                 'eclipsed': False,
#                 'elevation': 77.46,
#                 'ra': 1.9100706,
#                 'sataltitude': 12196.06,
#                 'satlatitude': 25.23224976,
#                 'satlongitude': 76.08681338,
#                 'timestamp': 1682398411},
#                {'azimuth': 182.73,
#                 'dec': 20.84456369,
#                 'eclipsed': False,
#                 'elevation': 77.48,
#                 'ra': 1.91767248,
#                 'sataltitude': 12199.65,
#                 'satlatitude': 25.24268723,
#                 'satlongitude': 76.08913481,
#                 'timestamp': 1682398412},
#                {'azimuth': 182.72,
#                 'dec': 20.86150509,
#                 'eclipsed': False,
#                 'elevation': 77.5,
#                 'ra': 1.92527225,
#                 'sataltitude': 12203.23,
#                 'satlatitude': 25.2531208,
#                 'satlongitude': 76.09145494,
#                 'timestamp': 1682398413},
#                {'azimuth': 182.71,
#                 'dec': 20.87843588,
#                 'eclipsed': False,
#                 'elevation': 77.52,
#                 'ra': 1.9328693,
#                 'sataltitude': 12206.82,
#                 'satlatitude': 25.26354963,
#                 'satlongitude': 76.09377358,
#                 'timestamp': 1682398414},
#                {'azimuth': 182.7,
#                 'dec': 20.89535674,
#                 'eclipsed': False,
#                 'elevation': 77.53,
#                 'ra': 1.94046393,
#                 'sataltitude': 12210.41,
#                 'satlatitude': 25.27397415,
#                 'satlongitude': 76.09609083,
#                 'timestamp': 1682398415},
#                {'azimuth': 182.68,
#                 'dec': 20.91226769,
#                 'eclipsed': False,
#                 'elevation': 77.55,
#                 'ra': 1.94805616,
#                 'sataltitude': 12213.99,
#                 'satlatitude': 25.28439434,
#                 'satlongitude': 76.09840669,
#                 'timestamp': 1682398416},
#                {'azimuth': 182.67,
#                 'dec': 20.92916872,
#                 'eclipsed': False,
#                 'elevation': 77.57,
#                 'ra': 1.95564598,
#                 'sataltitude': 12217.58,
#                 'satlatitude': 25.29481023,
#                 'satlongitude': 76.10072115,
#                 'timestamp': 1682398417},
#                {'azimuth': 182.66,
#                 'dec': 20.94605986,
#                 'eclipsed': False,
#                 'elevation': 77.58,
#                 'ra': 1.9632334,
#                 'sataltitude': 12221.16,
#                 'satlatitude': 25.30522181,
#                 'satlongitude': 76.10303423,
#                 'timestamp': 1682398418},
#                {'azimuth': 182.65,
#                 'dec': 20.96294111,
#                 'eclipsed': False,
#                 'elevation': 77.6,
#                 'ra': 1.97081842,
#                 'sataltitude': 12224.75,
#                 'satlatitude': 25.31562908,
#                 'satlongitude': 76.10534591,
#                 'timestamp': 1682398419},
#                {'azimuth': 182.64,
#                 'dec': 20.97981316,
#                 'eclipsed': False,
#                 'elevation': 77.62,
#                 'ra': 1.97840134,
#                 'sataltitude': 12228.33,
#                 'satlatitude': 25.32603246,
#                 'satlongitude': 76.1076563,
#                 'timestamp': 1682398420},
#                {'azimuth': 182.63,
#                 'dec': 20.99667397,
#                 'eclipsed': False,
#                 'elevation': 77.64,
#                 'ra': 1.98598126,
#                 'sataltitude': 12231.91,
#                 'satlatitude': 25.33643071,
#                 'satlongitude': 76.10996512,
#                 'timestamp': 1682398421},
#                {'azimuth': 182.61,
#                 'dec': 21.01352627,
#                 'eclipsed': False,
#                 'elevation': 77.65,
#                 'ra': 1.99355939,
#                 'sataltitude': 12235.5,
#                 'satlatitude': 25.34682549,
#                 'satlongitude': 76.11227274,
#                 'timestamp': 1682398422},
#                {'azimuth': 182.6,
#                 'dec': 21.03036804,
#                 'eclipsed': False,
#                 'elevation': 77.67,
#                 'ra': 2.00113482,
#                 'sataltitude': 12239.08,
#                 'satlatitude': 25.35721557,
#                 'satlongitude': 76.11457888,
#                 'timestamp': 1682398423},
#                {'azimuth': 182.59,
#                 'dec': 21.04719995,
#                 'eclipsed': False,
#                 'elevation': 77.69,
#                 'ra': 2.00870786,
#                 'sataltitude': 12242.66,
#                 'satlatitude': 25.36760135,
#                 'satlongitude': 76.11688363,
#                 'timestamp': 1682398424},
#                {'azimuth': 182.58,
#                 'dec': 21.06402202,
#                 'eclipsed': False,
#                 'elevation': 77.7,
#                 'ra': 2.01627852,
#                 'sataltitude': 12246.25,
#                 'satlatitude': 25.37798284,
#                 'satlongitude': 76.119187,
#                 'timestamp': 1682398425},
#                {'azimuth': 182.57,
#                 'dec': 21.08083427,
#                 'eclipsed': False,
#                 'elevation': 77.72,
#                 'ra': 2.02384678,
#                 'sataltitude': 12249.83,
#                 'satlatitude': 25.38836004,
#                 'satlongitude': 76.121489,
#                 'timestamp': 1682398426},
#                {'azimuth': 182.56,
#                 'dec': 21.09763736,
#                 'eclipsed': False,
#                 'elevation': 77.74,
#                 'ra': 2.03141297,
#                 'sataltitude': 12253.41,
#                 'satlatitude': 25.39873338,
#                 'satlongitude': 76.1237897,
#                 'timestamp': 1682398427},
#                {'azimuth': 182.54,
#                 'dec': 21.11442928,
#                 'eclipsed': False,
#                 'elevation': 77.75,
#                 'ra': 2.03897617,
#                 'sataltitude': 12256.99,
#                 'satlatitude': 25.4091016,
#                 'satlongitude': 76.12608884,
#                 'timestamp': 1682398428},
#                {'azimuth': 182.53,
#                 'dec': 21.13121274,
#                 'eclipsed': False,
#                 'elevation': 77.77,
#                 'ra': 2.0465376,
#                 'sataltitude': 12260.57,
#                 'satlatitude': 25.41946638,
#                 'satlongitude': 76.12838679,
#                 'timestamp': 1682398429},
#                {'azimuth': 182.52,
#                 'dec': 21.14798573,
#                 'eclipsed': False,
#                 'elevation': 77.79,
#                 'ra': 2.05409635,
#                 'sataltitude': 12264.15,
#                 'satlatitude': 25.42982647,
#                 'satlongitude': 76.13068326,
#                 'timestamp': 1682398430},
#                {'azimuth': 182.51,
#                 'dec': 21.16474893,
#                 'eclipsed': False,
#                 'elevation': 77.8,
#                 'ra': 2.06165273,
#                 'sataltitude': 12267.73,
#                 'satlatitude': 25.44018228,
#                 'satlongitude': 76.13297836,
#                 'timestamp': 1682398431},
#                {'azimuth': 182.5,
#                 'dec': 21.18150234,
#                 'eclipsed': False,
#                 'elevation': 77.82,
#                 'ra': 2.06920673,
#                 'sataltitude': 12271.32,
#                 'satlatitude': 25.45053383,
#                 'satlongitude': 76.13527209,
#                 'timestamp': 1682398432},
#                {'azimuth': 182.49,
#                 'dec': 21.19824597,
#                 'eclipsed': False,
#                 'elevation': 77.84,
#                 'ra': 2.07675836,
#                 'sataltitude': 12274.89,
#                 'satlatitude': 25.46088111,
#                 'satlongitude': 76.13756444,
#                 'timestamp': 1682398433},
#                {'azimuth': 182.47,
#                 'dec': 21.21497984,
#                 'eclipsed': False,
#                 'elevation': 77.85,
#                 'ra': 2.08430763,
#                 'sataltitude': 12278.47,
#                 'satlatitude': 25.47122412,
#                 'satlongitude': 76.13985542,
#                 'timestamp': 1682398434},
#                {'azimuth': 182.46,
#                 'dec': 21.23170395,
#                 'eclipsed': False,
#                 'elevation': 77.87,
#                 'ra': 2.09185453,
#                 'sataltitude': 12282.05,
#                 'satlatitude': 25.48156288,
#                 'satlongitude': 76.14214502,
#                 'timestamp': 1682398435},
#                {'azimuth': 182.45,
#                 'dec': 21.24841897,
#                 'eclipsed': False,
#                 'elevation': 77.89,
#                 'ra': 2.09939937,
#                 'sataltitude': 12285.63,
#                 'satlatitude': 25.49189779,
#                 'satlongitude': 76.14443335,
#                 'timestamp': 1682398436},
#                {'azimuth': 182.44,
#                 'dec': 21.26512359,
#                 'eclipsed': False,
#                 'elevation': 77.91,
#                 'ra': 2.10694155,
#                 'sataltitude': 12289.21,
#                 'satlatitude': 25.50222803,
#                 'satlongitude': 76.14672022,
#                 'timestamp': 1682398437},
#                {'azimuth': 182.43,
#                 'dec': 21.28181846,
#                 'eclipsed': False,
#                 'elevation': 77.92,
#                 'ra': 2.11448137,
#                 'sataltitude': 12292.79,
#                 'satlatitude': 25.51255402,
#                 'satlongitude': 76.14900572,
#                 'timestamp': 1682398438},
#                {'azimuth': 182.41,
#                 'dec': 21.29850361,
#                 'eclipsed': False,
#                 'elevation': 77.94,
#                 'ra': 2.12201883,
#                 'sataltitude': 12296.37,
#                 'satlatitude': 25.52287576,
#                 'satlongitude': 76.15128985,
#                 'timestamp': 1682398439}]}

# %% [markdown]
# ## The User Interface

# %%
import tkinter
class App(tkinter.Tk):

    APP_NAME = " Satellite orbits"
    WIDTH = 800
    HEIGHT = 750
    # Below is the sample data used off the REST call made 
    # https://api.n2yo.com/rest/v1/satellite/positions/25544/41.702/-76.014/ {} / {} /&apiKey=589P8Q-SDRYX8-L842ZD-5Z9
    positions = gps_position_data

    # positions = [ 
    #     {
    #         "satlatitude": 48.93831553,
    #         "satlongitude": 32.20823369,
    #         "sataltitude": 423.48,
    #         "azimuth": 41.74,
    #         "elevation": -32.18,
    #         "ra": 42.47092063,
    #         "dec": 6.65551562,
    #         "timestamp": 1682065020,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.91655743,
    #         "satlongitude": 32.29639533,
    #         "sataltitude": 423.47,
    #         "azimuth": 41.72,
    #         "elevation": -32.21,
    #         "ra": 42.50814991,
    #         "dec": 6.63768375,
    #         "timestamp": 1682065021,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.89472547,
    #         "satlongitude": 32.3844769,
    #         "sataltitude": 423.46,
    #         "azimuth": 41.7,
    #         "elevation": -32.24,
    #         "ra": 42.54534878,
    #         "dec": 6.61983002,
    #         "timestamp": 1682065022,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.87281887,
    #         "satlongitude": 32.4724818,
    #         "sataltitude": 423.45,
    #         "azimuth": 41.68,
    #         "elevation": -32.27,
    #         "ra": 42.58251879,
    #         "dec": 6.60195376,
    #         "timestamp": 1682065023,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.85083954,
    #         "satlongitude": 32.5604028,
    #         "sataltitude": 423.44,
    #         "azimuth": 41.65,
    #         "elevation": -32.3,
    #         "ra": 42.61965701,
    #         "dec": 6.58405647,
    #         "timestamp": 1682065024,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.82878669,
    #         "satlongitude": 32.64824333,
    #         "sataltitude": 423.43,
    #         "azimuth": 41.63,
    #         "elevation": -32.34,
    #         "ra": 42.65676499,
    #         "dec": 6.5661375,
    #         "timestamp": 1682065025,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.80666046,
    #         "satlongitude": 32.73600323,
    #         "sataltitude": 423.42,
    #         "azimuth": 41.61,
    #         "elevation": -32.37,
    #         "ra": 42.6938428,
    #         "dec": 6.54819689,
    #         "timestamp": 1682065026,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.78446096,
    #         "satlongitude": 32.82368238,
    #         "sataltitude": 423.41,
    #         "azimuth": 41.58,
    #         "elevation": -32.4,
    #         "ra": 42.73089049,
    #         "dec": 6.53023472,
    #         "timestamp": 1682065027,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.76218832,
    #         "satlongitude": 32.91128064,
    #         "sataltitude": 423.41,
    #         "azimuth": 41.56,
    #         "elevation": -32.43,
    #         "ra": 42.76790814,
    #         "dec": 6.51225103,
    #         "timestamp": 1682065028,
    #         "eclipsed": False
    #     },
    #     {
    #         "satlatitude": 48.73984265,
    #         "satlongitude": 32.99879788,
    #         "sataltitude": 423.4,
    #         "azimuth": 41.54,
    #         "elevation": -32.46,
    #         "ra": 42.8048958,
    #         "dec": 6.49424589,
    #         "timestamp": 1682065029,
    #         "eclipsed": False
    #     }
    # ]


    
    def __init__(self, *args, **kwargs):
        tkinter.Tk.__init__(self, *args, **kwargs)
        print(self.positions)

        self.title(self.APP_NAME)
        self.geometry(f"{self.WIDTH}x{self.HEIGHT}")

        self.protocol("WM_DELETE_WINDOW", self.on_closing)
        self.bind("<Return>", self.search)

        if sys.platform == "darwin":
            self.bind("<Command-q>", self.on_closing)
            self.bind("<Command-w>", self.on_closing)

        self.grid_columnconfigure(0, weight=1)
        self.grid_columnconfigure(1, weight=0)
        self.grid_columnconfigure(2, weight=0)
        self.grid_rowconfigure(1, weight=1)
        
        self.search_bar = tkinter.Entry(self, width=50) 
        # Here we can give input in terms of ( 40.714, -74.006) latitude, longitude
        self.search_bar.grid(row=0, column=0, pady=10, padx=10, sticky="we")
        self.search_bar.focus()

        self.search_bar_button = tkinter.Button(
            master=self, width=8, text="Search", command=self.search)
        self.search_bar_button.grid(row=0, column=1, pady=10, padx=10)

        self.search_bar_clear = tkinter.Button(
            master=self, width=8, text="Clear", command=self.clear)
        self.search_bar_clear.grid(row=0, column=2, pady=10, padx=10)

        self.map_widget = TkinterMapView(
            width=self.WIDTH, height=600, corner_radius=0)
        self.map_widget.grid(row=1, column=0, columnspan=3, sticky="nsew")

        self.marker_list_box = tkinter.Listbox(self, height=8)
        self.marker_list_box.grid(row=2, column=0, columnspan=1, sticky="ew", padx=10, pady=10)

        self.listbox_button_frame = tkinter.Frame(master=self)
        self.listbox_button_frame.grid( 
            row=2, column=1, sticky="nsew", columnspan=2)

        self.listbox_button_frame.grid_columnconfigure(0, weight=1)

        # self.show_satellite_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="get satellite coordinates",
        #                                             command=self.get_satellite_coordinates)
        # self.show_satellite_marker_button.grid(row=2, column=0, pady=10, padx=10)

        self.save_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="save current marker",
                                                 command=self.save_marker)
        self.save_marker_button.grid(row=0, column=0, pady=10, padx=10)

        self.clear_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="get satellite coordinates",
                                                  command=self.get_satellite_coordinates)
        self.clear_marker_button.grid(row=1, column=0, pady=10, padx=10)

        self.connect_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="connect marker with path",
                                                    command=self.connect_marker)
        self.connect_marker_button.grid(row=2, column=0, pady=10, padx=10)

        # This is the default addresss that the map would show
        self.map_widget.set_address("Jammu, India")

        self.marker_list = []
        self.marker_path = None

        self.search_marker = None
        self.search_in_progress = False

    def search(self, event=None):
        if not self.search_in_progress:   # IF search is not in progress then enters IF loop
            self.search_in_progress = True
            if self.search_marker not in self.marker_list:
                self.map_widget.delete(self.search_marker)

            # getting the location entered in the search bar
            address = self.search_bar.get()
            # print("***** Printing the type of the address {}".format(type(address))) # This is always string

            # print( geocoder.osm(address).latlng)
            # print( type( geocoder.osm(address).latlng) )
            latitude = geocoder.osm(address).latlng[0]
            longitude = geocoder.osm(address).latlng[1]

            print( "*********   Printing input {} \t latitude and longitude  {} {}".format(address, latitude, longitude ) )
            latlong = str( str(latitude)+ " " +str(longitude) )

#########################################
 # Plotting for satellite positions
            # for i in self.positions:
            #     latitude = (i.get('satlatitude'))
            #     longitude =(i.get('satlongitude'))
            #     latlong = str( str(latitude)+ " " +str(longitude) )
            
            # # Checking to see if the latitude and longitude are being concatinated as expected for input to the setAddress function
            #     print( "*********   Printing input latitude and longitude  {}".format(latlong) )
            
            self.search_marker = self.map_widget.set_address(
            address , marker=True )
            self.save_marker()

            ############## This is the function call for setting satellite's loc marker
            # self.set_satellite_map_marker(latitude, longitude)

            if self.search_marker is False:
                # address was invalid (return value is False)
                self.search_marker = None
            # self.get_satellite_coordinates()
            self.search_in_progress = False

    def save_marker(self):
        print("\n inside Save_Marker()\n")
        if self.search_marker is not None:
            # print("****** Printing inside Save Marker")
            # print(self.search_marker)
            self.marker_list_box.insert(
                tkinter.END, f" {len(self.marker_list)}. {self.search_marker.text} ")
            self.marker_list_box.see(tkinter.END)
            self.marker_list.append(self.search_marker)

    def clear_marker_list(self):
        for marker in self.marker_list:
            self.map_widget.delete(marker)

        self.marker_list_box.delete(0, tkinter.END)
        self.marker_list.clear()
        self.connect_marker()

    def connect_marker(self):
        print("\tInside connect_marker() \n")
        # print("\t\tprinting the marker_List \n {}".format(self.marker_list) )
        position_list = []

        for marker in self.marker_list:
            position_list.append(marker.position)

        if self.marker_path is not None:
            self.map_widget.delete(self.marker_path)

        if len(position_list) > 0:
            print("+++++++ . Printing Connect Marker position List here {}".format(position_list))
            self.marker_path = self.map_widget.set_path(position_list)

    def clear(self):
        self.search_bar.delete(0, last=tkinter.END)
        self.map_widget.delete(self.search_marker)

    def on_closing(self, event=0):
        self.destroy()
        exit()

    def start(self):
        self.mainloop()


    # This function is to set markers based on the lat and long for 150 min duration
    def set_satellite_map_marker(self, lat, long):
        # print("Latitude {} /t Longitude {}".format(lat, long))
        self.map_widget.set_marker(lat, long)
        self.save_satellite_marker(lat, long)
        self.connect_satellite_marker()

    # Dummy function
    def connect_satellite_marker(self):
        for index, value in enumerate(self.marker_list):
            print("Index {} , {} \t values: {} {}".format(index, index+1, self.marker_list[index], self.marker_list[index+1] ))
        # self.map_widget.set_path() # this takes an input list only
    
    # Function to save the satellite marker into the marker list
    def save_satellite_marker(self, satAddress):
        if self.search_marker is not None:
            
            self.marker_list_box.insert(
                tkinter.END, f" {len(self.marker_list)}. {satAddress} ")
            self.marker_list_box.see(tkinter.END)
            self.marker_list.append(self.search_marker)


    # Function to make HTTP requests 
    def get_satellite_coordinates(self):
        print("Inside get_Satellite_coordinates() \n")
        print( "*********   Printing input latitude and longitude @ Timestamp \n.")
    #  PLotting for satellite positions
        for i in self.positions.get('positions'):
            latitude = (i.get('satlatitude'))
            longitude =(i.get('satlongitude'))
            timestamp = dt.datetime.utcfromtimestamp(i.get('timestamp'))
#             print("{} {} @ {}".format(latitude, longitude, timestamp ))
            latlong = str( str(latitude)+ " " +str(longitude) )
        
        # Checking to see if the latitude and longitude are being concatinated as expected for input to the setAddress function
            print( "{} @ {} \n".format(latlong, dt.datetime.utcfromtimestamp(i.get('timestamp'))) )

        # Reverse Geocoding the latitude and longitude before setting the address down below
            locator = Nominatim(user_agent="sample")
            coordinates = tuple( ( latitude, longitude ))
            location = locator.reverse(coordinates)
            satAddress = location.address
            print(" \t \t Satellite is at  {} \n".format(satAddress) )
            self.search_marker = self.map_widget.set_address(
                satAddress , marker=True )
            # self.save_marker()
            self.save_satellite_marker(satAddress)

if __name__ == "__main__":
    app = App()
    app.start()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import tkinter
# ----> 2 class App(tkinter.Tk):
#       4     APP_NAME = " Satellite orbits"
#       5     WIDTH = 800
#
# Cell In[3], line 9, in App()
#       6 HEIGHT = 750
#       7 # Below is the sample data used off the REST call made
#       8 # https://api.n2yo.com/rest/v1/satellite/positions/25544/41.702/-76.014/ {} / {} /&apiKey=589P8Q-SDRYX8-L842ZD-5Z9
# ----> 9 positions = gps_position_data
#      11 # positions = [
#      12 #     {
#      13 #         "satlatitude": 48.93831553,
#    (...)
#     121 #     }
#     122 # ]
#     126 def __init__(self, *args, **kwargs):
#
# NameError: name 'gps_position_data' is not defined

# %%
# print(type(above_satellite_request))
# Out:
# <class 'requests.models.Response'>
