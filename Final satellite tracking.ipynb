# %% [markdown]
# ### All import statements exists here

# %%
import geocoder
import sys
import tkinter
import tkinter.messagebox
from tkintermapview import TkinterMapView
import geocoder
from geopy.geocoders import Nominatim
import datetime as dt
import requests
import json
import pprint

# %% [markdown]
# ## Find the Satellites that are above our head

# %%
class satlAboveHead:
    # geocoder.ip('me') is used to get current location in latitude and longitude
    locPlaceHldr = geocoder.ip('me')
    location = locPlaceHldr.latlng
    print(" The Current Location is: {}".format(location))
        # print("{}, {}".format(location[0], location[1]))

    url_str = "https://api.n2yo.com/rest/v1/satellite/above/"

    # USing the below line for manual testing only
    # latitude, longitude = "44.2367", "66.3287"

    Currentlatitude, Currentlongitude = str(location[0]), str(location[1])

    # This below value 10 would provide a search radius of *** km 
    #      at altitude of 1000km from observer's posn
    leading_url = "32.20279/76.31772/0/5/18/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7"
    # final_url = url_str+Currentlatitude+"/"+Currentlongitude+"/"+leading_url
    # final_url = url_str+"/"+leading_url                                    / /{radius}/ satlType
    final_url = "https://api.n2yo.com/rest/v1/satellite/above/32.7353/74.8617/0/70/18/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7"
    print(url_str+Currentlatitude+"/"+Currentlongitude+"/"+leading_url)

    above_satellite_request = requests.get(final_url)
    print("Response from making REST call {}".format(above_satellite_request))

    if(above_satellite_request.json() is None):
        tkinter.messagebox.showwarning(title = "BLZ", message = "You are in Black Out Zone")
        



## For Testing Purposes
#    
#     above_satellite_request = {
#         'info': {'category': 'Military', 'transactionscount': 16, 'satcount': 2}, 
#         'above': [{'satid': 15226, 'satname': 'USA 4', 'intDesignator': '1984-091A', 'launchDate': '1984-08-28', 'satlat': 38.5148, 'satlng': 71.7089, 'satalt': 28064.2029},
#            {'satid': 37212, 'satname': 'MERIDIAN 3', 'intDesignator': '2010-058A', 'launchDate': '2010-11-02', 'satlat': 34.3076, 'satlng': 83.4851, 'satalt': 19142.1263}
#           ]
# }
 # above_no_of_satellites = above_satellite_request['info']['satcount']  # TO be used for testing purpose only
    # print(above_satellite_request.json())
    # print(above_satellite_request.json()['info']['satcount'])
    
    above_no_of_satellites = above_satellite_request.json().get('info')['satcount']

    # print(above_no_of_satellites)
    # print("\n")
    # print(above_satellite_request.json())

    ## This Code is WORKING
# Here's a sample output of the request made

# {'info': {'category': 'Military', 'transactionscount': 16, 'satcount': 2}, 
#  'above': [{'satid': 15226, 'satname': 'USA 4', 'intDesignator': '1984-091A', 'launchDate': '1984-08-28', 'satlat': 38.5148, 'satlng': 71.7089, 'satalt': 28064.2029},
#            {'satid': 37212, 'satname': 'MERIDIAN 3', 'intDesignator': '2010-058A', 'launchDate': '2010-11-02', 'satlat': 34.3076, 'satlng': 83.4851, 'satalt': 19142.1263}
#           ]
# }
# Out:
#  The Current Location is: [34.0857, 74.8055]
# https://api.n2yo.com/rest/v1/satellite/above/34.0857/74.8055/32.20279/76.31772/0/5/18/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
# Response from making REST call <Response [200]>

# %% [markdown]
# ## Retreiving the positions of the satl mentioned above

# %%
class getSatlPosn:
    obj = satlAboveHead()
    satlPosnData = []
    gps_position_data_from_above_satellite = []
    # This initialization would be done only if input is not None 
    # print("{} {}".format(type(obj.above_satellite_request.json()), obj.above_satellite_request.json()))
    # print(type(obj.above_satellite_request))

    if( bool(obj.above_satellite_request)): 
        gps_position_data_from_above_satellite = obj.above_satellite_request.json()['above']
    else:
        satlPosnData = None
        print("Value with None exists")
    
    # print(gps_position_data.keys())
    print(gps_position_data_from_above_satellite)
    print("There are {} Military Satellites on top of your head. ".format(obj.above_no_of_satellites)) # THis returns the count of military satellites
    
    url_str = "http://api.n2yo.com/rest/v1/satellite/positions/"
    latitude = str(33.496552592013906)
    longitude = str(76.52195669878829)
    leading_url = "0/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7"

    print("\n Satellites are revolving on top of india: ")
    count = 1
    for i in gps_position_data_from_above_satellite:
        if(count !=3 ):
            print("\n {}".format(i['satid']) )

            sat_id = str(i['satid'])
            final_url = url_str+sat_id+"/"+latitude+"/"+longitude+"/"+leading_url
            print(final_url+"\n")
            # Making the REST call
            req = requests.get(final_url)
            pprint.pprint(req.json())
            # print("\n")
            satlPosnData.insert(i['satid'],req.json())
            count+=1
        else:
            break
        
    print(satlPosnData)
# Out:
# [{'satid': 1293, 'satname': 'OSCAR 3', 'intDesignator': '1965-016F', 'launchDate': '1965-03-09', 'satlat': 43.8301, 'satlng': 64.5277, 'satalt': 868.5998}, {'satid': 39769, 'satname': 'RISING 2', 'intDesignator': '2014-029D', 'launchDate': '2014-05-24', 'satlat': 39.2481, 'satlng': 65.9814, 'satalt': 625.9077}, {'satid': 43700, 'satname': "ES'HAIL 2 (QO-100)", 'intDesignator': '2018-090A', 'launchDate': '2018-11-15', 'satlat': 0.0307, 'satlng': 25.7904, 'satalt': 35785.7815}, {'satid': 44420, 'satname': 'LIGHTSAIL 2', 'intDesignator': '2019-036AC', 'launchDate': '2019-06-25', 'satlat': -18.2471, 'satlng': 33.8302, 'satalt': 46821091446293.47}]
# There are 4 Military Satellites on top of your head.
#
#  Satellites are revolving on top of india:
#
#  1293
# http://api.n2yo.com/rest/v1/satellite/positions/1293/33.496552592013906/76.52195669878829/0/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
#
# {'info': {'satid': 1293, 'satname': 'OSCAR 3', 'transactionscount': 164},
#  'positions': [{'azimuth': 321,
#                 'dec': 53.3413915,
#                 'eclipsed': False,
#                 'elevation': 21.12,
#                 'ra': 340.20806979,
#                 'sataltitude': 868.51,
#                 'satlatitude': 43.62246799,
#                 'satlongitude': 64.6678129,
#                 'timestamp': 1686638992},
#                {'azimuth': 320.92,
#                 'dec': 53.32641202,
#                 'eclipsed': False,
#                 'elevation': 21.24,
#                 'ra': 340.45297627,
#                 'sataltitude': 868.49,
#                 'satlatitude': 43.57053091,
#                 'satlongitude': 64.70162774,
#                 'timestamp': 1686638993},
#                {'azimuth': 320.83,
#                 'dec': 53.310744,
#                 'eclipsed': False,
#                 'elevation': 21.36,
#                 'ra': 340.69891652,
#                 'sataltitude': 868.46,
#                 'satlatitude': 43.5185785,
#                 'satlongitude': 64.7353789,
#                 'timestamp': 1686638994},
#                {'azimuth': 320.74,
#                 'dec': 53.29438033,
#                 'eclipsed': False,
#                 'elevation': 21.48,
#                 'ra': 340.94586979,
#                 'sataltitude': 868.44,
#                 'satlatitude': 43.46661499,
#                 'satlongitude': 64.76906388,
#                 'timestamp': 1686638995},
#                {'azimuth': 320.65,
#                 'dec': 53.27731195,
#                 'eclipsed': False,
#                 'elevation': 21.61,
#                 'ra': 341.19384483,
#                 'sataltitude': 868.42,
#                 'satlatitude': 43.41463832,
#                 'satlongitude': 64.80268426,
#                 'timestamp': 1686638996},
#                {'azimuth': 320.56,
#                 'dec': 53.25953036,
#                 'eclipsed': False,
#                 'elevation': 21.73,
#                 'ra': 341.44284038,
#                 'sataltitude': 868.39,
#                 'satlatitude': 43.36264854,
#                 'satlongitude': 64.83624023,
#                 'timestamp': 1686638997},
#                {'azimuth': 320.47,
#                 'dec': 53.24102696,
#                 'eclipsed': False,
#                 'elevation': 21.85,
#                 'ra': 341.69285503,
#                 'sataltitude': 868.37,
#                 'satlatitude': 43.31064569,
#                 'satlongitude': 64.86973201,
#                 'timestamp': 1686638998},
#                {'azimuth': 320.37,
#                 'dec': 53.22179309,
#                 'eclipsed': False,
#                 'elevation': 21.97,
#                 'ra': 341.94388722,
#                 'sataltitude': 868.35,
#                 'satlatitude': 43.25862983,
#                 'satlongitude': 64.90315982,
#                 'timestamp': 1686638999},
#                {'azimuth': 320.28,
#                 'dec': 53.20181998,
#                 'eclipsed': False,
#                 'elevation': 22.1,
#                 'ra': 342.19593524,
#                 'sataltitude': 868.33,
#                 'satlatitude': 43.20660098,
#                 'satlongitude': 64.93652386,
#                 'timestamp': 1686639000},
#                {'azimuth': 320.19,
#                 'dec': 53.18109797,
#                 'eclipsed': False,
#                 'elevation': 22.22,
#                 'ra': 342.44900743,
#                 'sataltitude': 868.3,
#                 'satlatitude': 43.1545571,
#                 'satlongitude': 64.96982568,
#                 'timestamp': 1686639001},
#                {'azimuth': 320.09,
#                 'dec': 53.15961981,
#                 'eclipsed': False,
#                 'elevation': 22.35,
#                 'ra': 342.70308141,
#                 'sataltitude': 868.28,
#                 'satlatitude': 43.10250243,
#                 'satlongitude': 65.00306281,
#                 'timestamp': 1686639002},
#                {'azimuth': 320,
#                 'dec': 53.13737571,
#                 'eclipsed': False,
#                 'elevation': 22.47,
#                 'ra': 342.95816517,
#                 'sataltitude': 868.26,
#                 'satlatitude': 43.0504349,
#                 'satlongitude': 65.03623679,
#                 'timestamp': 1686639003},
#                {'azimuth': 319.9,
#                 'dec': 53.11435661,
#                 'eclipsed': False,
#                 'elevation': 22.6,
#                 'ra': 343.21425636,
#                 'sataltitude': 868.24,
#                 'satlatitude': 42.99835457,
#                 'satlongitude': 65.06934783,
#                 'timestamp': 1686639004},
#                {'azimuth': 319.81,
#                 'dec': 53.09055336,
#                 'eclipsed': False,
#                 'elevation': 22.72,
#                 'ra': 343.47135249,
#                 'sataltitude': 868.21,
#                 'satlatitude': 42.94626147,
#                 'satlongitude': 65.10239614,
#                 'timestamp': 1686639005},
#                {'azimuth': 319.71,
#                 'dec': 53.06595675,
#                 'eclipsed': False,
#                 'elevation': 22.85,
#                 'ra': 343.7294509,
#                 'sataltitude': 868.19,
#                 'satlatitude': 42.89415565,
#                 'satlongitude': 65.13538192,
#                 'timestamp': 1686639006},
#                {'azimuth': 319.61,
#                 'dec': 53.04055749,
#                 'eclipsed': False,
#                 'elevation': 22.98,
#                 'ra': 343.98854876,
#                 'sataltitude': 868.17,
#                 'satlatitude': 42.84203714,
#                 'satlongitude': 65.16830537,
#                 'timestamp': 1686639007},
#                {'azimuth': 319.51,
#                 'dec': 53.01434514,
#                 'eclipsed': False,
#                 'elevation': 23.1,
#                 'ra': 344.24865356,
#                 'sataltitude': 868.15,
#                 'satlatitude': 42.7899039,
#                 'satlongitude': 65.20116803,
#                 'timestamp': 1686639008},
#                {'azimuth': 319.41,
#                 'dec': 52.98731235,
#                 'eclipsed': False,
#                 'elevation': 23.23,
#                 'ra': 344.5097412,
#                 'sataltitude': 868.12,
#                 'satlatitude': 42.73776015,
#                 'satlongitude': 65.23396745,
#                 'timestamp': 1686639009},
#                {'azimuth': 319.31,
#                 'dec': 52.95944857,
#                 'eclipsed': False,
#                 'elevation': 23.36,
#                 'ra': 344.7718188,
#                 'sataltitude': 868.1,
#                 'satlatitude': 42.68560385,
#                 'satlongitude': 65.26670515,
#                 'timestamp': 1686639010},
#                {'azimuth': 319.21,
#                 'dec': 52.9307442,
#                 'eclipsed': False,
#                 'elevation': 23.49,
#                 'ra': 345.03488284,
#                 'sataltitude': 868.08,
#                 'satlatitude': 42.63343504,
#                 'satlongitude': 65.29938133,
#                 'timestamp': 1686639011},
#                {'azimuth': 319.11,
#                 'dec': 52.90118956,
#                 'eclipsed': False,
#                 'elevation': 23.62,
#                 'ra': 345.29892965,
#                 'sataltitude': 868.05,
#                 'satlatitude': 42.58125375,
#                 'satlongitude': 65.3319962,
#                 'timestamp': 1686639012},
#                {'azimuth': 319,
#                 'dec': 52.87077491,
#                 'eclipsed': False,
#                 'elevation': 23.75,
#                 'ra': 345.56395535,
#                 'sataltitude': 868.03,
#                 'satlatitude': 42.52906002,
#                 'satlongitude': 65.36454995,
#                 'timestamp': 1686639013},
#                {'azimuth': 318.9,
#                 'dec': 52.83949041,
#                 'eclipsed': False,
#                 'elevation': 23.88,
#                 'ra': 345.82995591,
#                 'sataltitude': 868.01,
#                 'satlatitude': 42.47685391,
#                 'satlongitude': 65.39704279,
#                 'timestamp': 1686639014},
#                {'azimuth': 318.8,
#                 'dec': 52.80732486,
#                 'eclipsed': False,
#                 'elevation': 24.01,
#                 'ra': 346.09693786,
#                 'sataltitude': 867.99,
#                 'satlatitude': 42.42463334,
#                 'satlongitude': 65.42947622,
#                 'timestamp': 1686639015},
#                {'azimuth': 318.69,
#                 'dec': 52.77427221,
#                 'eclipsed': False,
#                 'elevation': 24.15,
#                 'ra': 346.36486453,
#                 'sataltitude': 867.96,
#                 'satlatitude': 42.37240466,
#                 'satlongitude': 65.46184651,
#                 'timestamp': 1686639016},
#                {'azimuth': 318.58,
#                 'dec': 52.74031711,
#                 'eclipsed': False,
#                 'elevation': 24.28,
#                 'ra': 346.63377446,
#                 'sataltitude': 867.94,
#                 'satlatitude': 42.32015951,
#                 'satlongitude': 65.49415909,
#                 'timestamp': 1686639017},
#                {'azimuth': 318.48,
#                 'dec': 52.70545347,
#                 'eclipsed': False,
#                 'elevation': 24.41,
#                 'ra': 346.90363046,
#                 'sataltitude': 867.92,
#                 'satlatitude': 42.26790423,
#                 'satlongitude': 65.52641024,
#                 'timestamp': 1686639018},
#                {'azimuth': 318.37,
#                 'dec': 52.66966976,
#                 'eclipsed': False,
#                 'elevation': 24.55,
#                 'ra': 347.17443839,
#                 'sataltitude': 867.9,
#                 'satlatitude': 42.21563675,
#                 'satlongitude': 65.55860145,
#                 'timestamp': 1686639019},
#                {'azimuth': 318.26,
#                 'dec': 52.63295571,
#                 'eclipsed': False,
#                 'elevation': 24.68,
#                 'ra': 347.4461931,
#                 'sataltitude': 867.87,
#                 'satlatitude': 42.16335713,
#                 'satlongitude': 65.59073293,
#                 'timestamp': 1686639020},
#                {'azimuth': 318.15,
#                 'dec': 52.59530098,
#                 'eclipsed': False,
#                 'elevation': 24.82,
#                 'ra': 347.71888925,
#                 'sataltitude': 867.85,
#                 'satlatitude': 42.11106539,
#                 'satlongitude': 65.62280487,
#                 'timestamp': 1686639021}]}
#
#  39769
# http://api.n2yo.com/rest/v1/satellite/positions/39769/33.496552592013906/76.52195669878829/0/30/&apiKey=SW2CQL-P78YQG-8MWP3V-50M7
#
# {'info': {'satid': 39769, 'satname': 'RISING 2', 'transactionscount': 165},
#  'positions': [{'azimuth': 305.05,
#                 'dec': 41.051459,
#                 'eclipsed': False,
#                 'elevation': 22.76,
#                 'ra': 352.10289929,
#                 'sataltitude': 625.84,
#                 'satlatitude': 38.88226923,
#                 'satlongitude': 65.87770103,
#                 'timestamp': 1686638994},
#                {'azimuth': 304.71,
#                 'dec': 40.78826451,
#                 'eclipsed': False,
#                 'elevation': 22.81,
#                 'ra': 352.34326493,
#                 'sataltitude': 625.83,
#                 'satlatitude': 38.82130138,
#                 'satlongitude': 65.85980629,
#                 'timestamp': 1686638995},
#                {'azimuth': 304.36,
#                 'dec': 40.52375814,
#                 'eclipsed': False,
#                 'elevation': 22.85,
#                 'ra': 352.58200563,
#                 'sataltitude': 625.82,
#                 'satlatitude': 38.76033128,
#                 'satlongitude': 65.8419349,
#                 'timestamp': 1686638996},
#                {'azimuth': 304.02,
#                 'dec': 40.25795778,
#                 'eclipsed': False,
#                 'elevation': 22.9,
#                 'ra': 352.81912684,
#                 'sataltitude': 625.81,
#                 'satlatitude': 38.69935892,
#                 'satlongitude': 65.82408675,
#                 'timestamp': 1686638997},
#                {'azimuth': 303.68,
#                 'dec': 39.99088156,
#                 'eclipsed': False,
#                 'elevation': 22.94,
#                 'ra': 353.05463416,
#                 'sataltitude': 625.8,
#                 'satlatitude': 38.6383843,
#                 'satlongitude': 65.80626177,
#                 'timestamp': 1686638998},
#                {'azimuth': 303.33,
#                 'dec': 39.72254787,
#                 'eclipsed': False,
#                 'elevation': 22.99,
#                 'ra': 353.28853339,
#                 'sataltitude': 625.79,
#                 'satlatitude': 38.57740745,
#                 'satlongitude': 65.78845986,
#                 'timestamp': 1686638999},
#                {'azimuth': 302.98,
#                 'dec': 39.45297531,
#                 'eclipsed': False,
#                 'elevation': 23.03,
#                 'ra': 353.52083047,
#                 'sataltitude': 625.78,
#                 'satlatitude': 38.51642835,
#                 'satlongitude': 65.77068093,
#                 'timestamp': 1686639000},
#                {'azimuth': 302.63,
#                 'dec': 39.18217184,
#                 'eclipsed': False,
#                 'elevation': 23.07,
#                 'ra': 353.75154075,
#                 'sataltitude': 625.77,
#                 'satlatitude': 38.45544458,
#                 'satlongitude': 65.75292418,
#                 'timestamp': 1686639001},
#                {'azimuth': 302.28,
#                 'dec': 38.9101783,
#                 'eclipsed': False,
#                 'elevation': 23.11,
#                 'ra': 353.98065195,
#                 'sataltitude': 625.76,
#                 'satlatitude': 38.39446103,
#                 'satlongitude': 65.73519096,
#                 'timestamp': 1686639002},
#                {'azimuth': 301.93,
#                 'dec': 38.63700314,
#                 'eclipsed': False,
#                 'elevation': 23.15,
#                 'ra': 354.20817977,
#                 'sataltitude': 625.75,
#                 'satlatitude': 38.33347526,
#                 'satlongitude': 65.71748045,
#                 'timestamp': 1686639003},
#                {'azimuth': 301.58,
#                 'dec': 38.36266588,
#                 'eclipsed': False,
#                 'elevation': 23.19,
#                 'ra': 354.43413077,
#                 'sataltitude': 625.74,
#                 'satlatitude': 38.27248729,
#                 'satlongitude': 65.69979258,
#                 'timestamp': 1686639004},
#                {'azimuth': 301.23,
#                 'dec': 38.08718627,
#                 'eclipsed': False,
#                 'elevation': 23.23,
#                 'ra': 354.65851163,
#                 'sataltitude': 625.73,
#                 'satlatitude': 38.21149711,
#                 'satlongitude': 65.68212726,
#                 'timestamp': 1686639005},
#                {'azimuth': 300.88,
#                 'dec': 37.81058426,
#                 'eclipsed': False,
#                 'elevation': 23.27,
#                 'ra': 354.88132915,
#                 'sataltitude': 625.72,
#                 'satlatitude': 38.15050473,
#                 'satlongitude': 65.6644844,
#                 'timestamp': 1686639006},
#                {'azimuth': 300.52,
#                 'dec': 37.53288001,
#                 'eclipsed': False,
#                 'elevation': 23.3,
#                 'ra': 355.10259027,
#                 'sataltitude': 625.71,
#                 'satlatitude': 38.08951015,
#                 'satlongitude': 65.64686391,
#                 'timestamp': 1686639007},
#                {'azimuth': 300.17,
#                 'dec': 37.25408265,
#                 'eclipsed': False,
#                 'elevation': 23.34,
#                 'ra': 355.32231086,
#                 'sataltitude': 625.69,
#                 'satlatitude': 38.02851094,
#                 'satlongitude': 65.629265,
#                 'timestamp': 1686639008},
#                {'azimuth': 299.81,
#                 'dec': 36.97423518,
#                 'eclipsed': False,
#                 'elevation': 23.37,
#                 'ra': 355.54048038,
#                 'sataltitude': 625.68,
#                 'satlatitude': 37.967512,
#                 'satlongitude': 65.61168901,
#                 'timestamp': 1686639009},
#                {'azimuth': 299.45,
#                 'dec': 36.69334716,
#                 'eclipsed': False,
#                 'elevation': 23.4,
#                 'ra': 355.757115,
#                 'sataltitude': 625.67,
#                 'satlatitude': 37.90651089,
#                 'satlongitude': 65.59413514,
#                 'timestamp': 1686639010},
#                {'azimuth': 299.1,
#                 'dec': 36.41143953,
#                 'eclipsed': False,
#                 'elevation': 23.44,
#                 'ra': 355.97222208,
#                 'sataltitude': 625.66,
#                 'satlatitude': 37.84550762,
#                 'satlongitude': 65.5766033,
#                 'timestamp': 1686639011},
#                {'azimuth': 298.74,
#                 'dec': 36.12853341,
#                 'eclipsed': False,
#                 'elevation': 23.47,
#                 'ra': 356.18580909,
#                 'sataltitude': 625.65,
#                 'satlatitude': 37.78450218,
#                 'satlongitude': 65.55909341,
#                 'timestamp': 1686639012},
#                {'azimuth': 298.38,
#                 'dec': 35.8446501,
#                 'eclipsed': False,
#                 'elevation': 23.5,
#                 'ra': 356.39788359,
#                 'sataltitude': 625.64,
#                 'satlatitude': 37.72349459,
#                 'satlongitude': 65.54160539,
#                 'timestamp': 1686639013},
#                {'azimuth': 298.02,
#                 'dec': 35.55981107,
#                 'eclipsed': False,
#                 'elevation': 23.52,
#                 'ra': 356.60845324,
#                 'sataltitude': 625.63,
#                 'satlatitude': 37.66248484,
#                 'satlongitude': 65.52413916,
#                 'timestamp': 1686639014},
#                {'azimuth': 297.66,
#                 'dec': 35.27402644,
#                 'eclipsed': False,
#                 'elevation': 23.55,
#                 'ra': 356.81753414,
#                 'sataltitude': 625.62,
#                 'satlatitude': 37.60147051,
#                 'satlongitude': 65.50669392,
#                 'timestamp': 1686639015},
#                {'azimuth': 297.3,
#                 'dec': 34.98735255,
#                 'eclipsed': False,
#                 'elevation': 23.58,
#                 'ra': 357.02510897,
#                 'sataltitude': 625.61,
#                 'satlatitude': 37.54045894,
#                 'satlongitude': 65.48927171,
#                 'timestamp': 1686639016},
#                {'azimuth': 296.94,
#                 'dec': 34.6997652,
#                 'eclipsed': False,
#                 'elevation': 23.6,
#                 'ra': 357.23121902,
#                 'sataltitude': 625.6,
#                 'satlatitude': 37.47944034,
#                 'satlongitude': 65.47186963,
#                 'timestamp': 1686639017},
#                {'azimuth': 296.57,
#                 'dec': 34.41132115,
#                 'eclipsed': False,
#                 'elevation': 23.63,
#                 'ra': 357.43584726,
#                 'sataltitude': 625.59,
#                 'satlatitude': 37.41842206,
#                 'satlongitude': 65.45448971,
#                 'timestamp': 1686639018},
#                {'azimuth': 296.21,
#                 'dec': 34.12203106,
#                 'eclipsed': False,
#                 'elevation': 23.65,
#                 'ra': 357.63901006,
#                 'sataltitude': 625.58,
#                 'satlatitude': 37.35740167,
#                 'satlongitude': 65.43713117,
#                 'timestamp': 1686639019},
#                {'azimuth': 295.85,
#                 'dec': 33.8319173,
#                 'eclipsed': False,
#                 'elevation': 23.67,
#                 'ra': 357.84071547,
#                 'sataltitude': 625.57,
#                 'satlatitude': 37.29637917,
#                 'satlongitude': 65.41979392,
#                 'timestamp': 1686639020},
#                {'azimuth': 295.48,
#                 'dec': 33.54100235,
#                 'eclipsed': False,
#                 'elevation': 23.69,
#                 'ra': 358.04097165,
#                 'sataltitude': 625.56,
#                 'satlatitude': 37.23535456,
#                 'satlongitude': 65.40247787,
#                 'timestamp': 1686639021},
#                {'azimuth': 295.12,
#                 'dec': 33.24929707,
#                 'eclipsed': False,
#                 'elevation': 23.71,
#                 'ra': 358.23979475,
#                 'sataltitude': 625.55,
#                 'satlatitude': 37.1743254,
#                 'satlongitude': 65.38518227,
#                 'timestamp': 1686639022},
#                {'azimuth': 294.76,
#                 'dec': 32.95685944,
#                 'eclipsed': False,
longitude': 64.86973201, 'sataltitude': 868.37, 'azimuth': 320.47, 'elevation': 21.85, 'ra': 341.69285503, 'dec': 53.24102696, 'timestamp': 1686638998, 'eclipsed': False}, {'satlatitude': 43.25862983, 'satlongitude': 64.90315982, 'sataltitude': 868.35, 'azimuth': 320.37, 'elevation': 21.97, 'ra': 341.94388722, 'dec': 53.22179309, 'timestamp': 1686638999, 'eclipsed': False}, {'satlatitude': 43.20660098, 'satlongitude': 64.93652386, 'sataltitude': 868.33, 'azimuth': 320.28, 'elevation': 22.1, 'ra': 342.19593524, 'dec': 53.20181998, 'timestamp': 1686639000, 'eclipsed': False}, {'satlatitude': 43.1545571, 'satlongitude': 64.96982568, 'sataltitude': 868.3, 'azimuth': 320.19, 'elevation': 22.22, 'ra': 342.44900743, 'dec': 53.18109797, 'timestamp': 1686639001, 'eclipsed': False}, {'satlatitude': 43.10250243, 'satlongitude': 65.00306281, 'sataltitude': 868.28, 'azimuth': 320.09, 'elevation': 22.35, 'ra': 342.70308141, 'dec': 53.15961981, 'timestamp': 1686639002, 'eclipsed': False}, {'satlatitude': 43.0504349, 'satlongitude': 65.03623679, 'sataltitude': 868.26, 'azimuth': 320, 'elevation': 22.47, 'ra': 342.95816517, 'dec': 53.13737571, 'timestamp': 1686639003, 'eclipsed': False}, {'satlatitude': 42.99835457, 'satlongitude': 65.06934783, 'sataltitude': 868.24, 'azimuth': 319.9, 'elevation': 22.6, 'ra': 343.21425636, 'dec': 53.11435661, 'timestamp': 1686639004, 'eclipsed': False}, {'satlatitude': 42.94626147, 'satlongitude': 65.10239614, 'sataltitude': 868.21, 'azimuth': 319.81, 'elevation': 22.72, 'ra': 343.47135249, 'dec': 53.09055336, 'timestamp': 1686639005, 'eclipsed': False}, {'satlatitude': 42.89415565, 'satlongitude': 65.13538192, 'sataltitude': 868.19, 'azimuth': 319.71, 'elevation': 22.85, 'ra': 343.7294509, 'dec': 53.06595675, 'timestamp': 1686639006, 'eclipsed': False}, {'satlatitude': 42.84203714, 'satlongitude': 65.16830537, 'sataltitude': 868.17, 'azimuth': 319.61, 'elevation': 22.98, 'ra': 343.98854876, 'dec': 53.04055749, 'timestamp': 1686639007, 'eclipsed': False}, {'satlatitude': 42.7899039, 'satlongitude': 65.20116803, 'sataltitude': 868.15, 'azimuth': 319.51, 'elevation': 23.1, 'ra': 344.24865356, 'dec': 53.01434514, 'timestamp': 1686639008, 'eclipsed': False}, {'satlatitude': 42.73776015, 'satlongitude': 65.23396745, 'sataltitude': 868.12, 'azimuth': 319.41, 'elevation': 23.23, 'ra': 344.5097412, 'dec': 52.98731235, 'timestamp': 1686639009, 'eclipsed': False}, {'satlatitude': 42.68560385, 'satlongitude': 65.26670515, 'sataltitude': 868.1, 'azimuth': 319.31, 'elevation': 23.36, 'ra': 344.7718188, 'dec': 52.95944857, 'timestamp': 1686639010, 'eclipsed': False}, {'satlatitude': 42.63343504, 'satlongitu ...

# %%
import tkinter
import numpy as np

class App(tkinter.Tk):

    obj = getSatlPosn()
    APP_NAME = " Satellite orbits"
    WIDTH = 800
    HEIGHT = 750
    latlong = []
    ownLatitude, ownLongitude = 0.0, 0.0
    ALatLongData = {   # This variable stores all the latitude and longitude data of all the 
    }

    # Below is the sample data used off the REST call made 
    # https://api.n2yo.com/rest/v1/satellite/positions/25544/41.702/-76.014/ {} / {} /&apiKey=589P8Q-SDRYX8-L842ZD-5Z9
    if( obj.satlPosnData is not None):
        positions = obj.satlPosnData
    else:

        tkinter.messagebox.showwarning(title = "BLZ", message = "Not in Black Out Zone")

# {
#     # positions = [ 
#     #     {
#     #         "satlatitude": 48.93831553,
#     #         "satlongitude": 32.20823369,
#     #         "sataltitude": 423.48,
#     #         "azimuth": 41.74,
#     #         "elevation": -32.18,
#     #         "ra": 42.47092063,
#     #         "dec": 6.65551562,
#     #         "timestamp": 1682065020,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.91655743,
#     #         "satlongitude": 32.29639533,
#     #         "sataltitude": 423.47,
#     #         "azimuth": 41.72,
#     #         "elevation": -32.21,
#     #         "ra": 42.50814991,
#     #         "dec": 6.63768375,
#     #         "timestamp": 1682065021,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.89472547,
#     #         "satlongitude": 32.3844769,
#     #         "sataltitude": 423.46,
#     #         "azimuth": 41.7,
#     #         "elevation": -32.24,
#     #         "ra": 42.54534878,
#     #         "dec": 6.61983002,
#     #         "timestamp": 1682065022,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.87281887,
#     #         "satlongitude": 32.4724818,
#     #         "sataltitude": 423.45,
#     #         "azimuth": 41.68,
#     #         "elevation": -32.27,
#     #         "ra": 42.58251879,
#     #         "dec": 6.60195376,
#     #         "timestamp": 1682065023,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.85083954,
#     #         "satlongitude": 32.5604028,
#     #         "sataltitude": 423.44,
#     #         "azimuth": 41.65,
#     #         "elevation": -32.3,
#     #         "ra": 42.61965701,
#     #         "dec": 6.58405647,
#     #         "timestamp": 1682065024,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.82878669,
#     #         "satlongitude": 32.64824333,
#     #         "sataltitude": 423.43,
#     #         "azimuth": 41.63,
#     #         "elevation": -32.34,
#     #         "ra": 42.65676499,
#     #         "dec": 6.5661375,
#     #         "timestamp": 1682065025,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.80666046,
#     #         "satlongitude": 32.73600323,
#     #         "sataltitude": 423.42,
#     #         "azimuth": 41.61,
#     #         "elevation": -32.37,
#     #         "ra": 42.6938428,
#     #         "dec": 6.54819689,
#     #         "timestamp": 1682065026,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.78446096,
#     #         "satlongitude": 32.82368238,
#     #         "sataltitude": 423.41,
#     #         "azimuth": 41.58,
#     #         "elevation": -32.4,
#     #         "ra": 42.73089049,
#     #         "dec": 6.53023472,
#     #         "timestamp": 1682065027,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.76218832,
#     #         "satlongitude": 32.91128064,
#     #         "sataltitude": 423.41,
#     #         "azimuth": 41.56,
#     #         "elevation": -32.43,
#     #         "ra": 42.76790814,
#     #         "dec": 6.51225103,
#     #         "timestamp": 1682065028,
#     #         "eclipsed": False
#     #     },
#     #     {
#     #         "satlatitude": 48.73984265,
#     #         "satlongitude": 32.99879788,
#     #         "sataltitude": 423.4,
#     #         "azimuth": 41.54,
#     #         "elevation": -32.46,
#     #         "ra": 42.8048958,
#     #         "dec": 6.49424589,
#     #         "timestamp": 1682065029,
#     #         "eclipsed": False
#     #     }
#     # ]
# }

    
    def __init__(self, *args, **kwargs):
        tkinter.Tk.__init__(self, *args, **kwargs)

        self.title(self.APP_NAME)
        self.geometry(f"{self.WIDTH}x{self.HEIGHT}")

        self.protocol("WM_DELETE_WINDOW", self.on_closing)
        self.bind("<Return>", self.search)

        if sys.platform == "darwin":
            self.bind("<Command-q>", self.on_closing)
            self.bind("<Command-w>", self.on_closing)

        self.grid_columnconfigure(0, weight=1)
        self.grid_columnconfigure(1, weight=0)
        self.grid_columnconfigure(2, weight=0)
        self.grid_rowconfigure(1, weight=1)
        
        self.search_bar = tkinter.Entry(self, width=50) 
        # Here we can give input in terms of ( 40.714, -74.006) latitude, longitude
        self.search_bar.grid(row=0, column=0, pady=10, padx=10, sticky="we")
        self.search_bar.focus()

        self.search_bar_button = tkinter.Button(
            master=self, width=8, text="Search", command=self.search)
        self.search_bar_button.grid(row=0, column=1, pady=10, padx=10)

        self.search_bar_clear = tkinter.Button(
            master=self, width=8, text="Clear", command=self.clear)
        self.search_bar_clear.grid(row=0, column=2, pady=10, padx=10)

        self.map_widget = TkinterMapView(
            width=self.WIDTH, height=600, corner_radius=0)
        self.map_widget.grid(row=1, column=0, columnspan=3, sticky="nsew")

        self.marker_list_box = tkinter.Listbox(self, height=8)
        self.marker_list_box.grid(row=2, column=0, columnspan=1, sticky="ew", padx=10, pady=10)

        self.listbox_button_frame = tkinter.Frame(master=self)
        self.listbox_button_frame.grid( 
            row=2, column=1, sticky="nsew", columnspan=2)

        self.listbox_button_frame.grid_columnconfigure(0, weight=1)

        self.save_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="save current marker",
                                                 command=self.save_marker)
        self.save_marker_button.grid(row=0, column=0, pady=10, padx=10)

        self.clear_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="get satellite coordinates",
                                                  command=self.get_satellite_coordinates)
        self.clear_marker_button.grid(row=1, column=0, pady=10, padx=10)

        self.connect_marker_button = tkinter.Button(master=self.listbox_button_frame, width=20, text="connect marker with path",
                                                    command=self.connect_marker)
        self.connect_marker_button.grid(row=2, column=0, pady=10, padx=10)

        # This is the default addresss that the map would show
        self.map_widget.set_address("Jammu, India")

        self.marker_list = []
        self.marker_path = None

        self.search_marker = None
        self.search_in_progress = False


    def search(self, event=None):
        if not self.search_in_progress:   # IF search is not in progress then enters IF loop
            self.search_in_progress = True
            if self.search_marker not in self.marker_list:
                self.map_widget.delete(self.search_marker)

            # getting the location entered in the search bar
            address = self.search_bar.get()
            latitude = geocoder.osm(address).latlng[0]
            longitude = geocoder.osm(address).latlng[1]

            print( "*********   Printing input {} \t latitude and longitude  {} {}".format(address, latitude, longitude ) )
            # latlong = str( str(latitude)+ " " +str(longitude) )
            
            self.search_marker = self.map_widget.set_address(
            address , marker=True )
            self.save_marker()

            if self.search_marker is False:
                # address was invalid (return value is False)
                self.search_marker = None
            # self.get_satellite_coordinates()
            self.search_in_progress = False
            return

    def save_marker(self):
        print("\n inside Save_Marker()\n")
        if self.search_marker is not None:
            # print("****** Printing inside Save Marker")
            # print(self.search_marker)
            self.marker_list_box.insert(
                tkinter.END, f" {len(self.marker_list)}. {self.search_marker.text} ")
            self.marker_list_box.see(tkinter.END)
            self.marker_list.append(self.search_marker)
    
        # Function to save the satellite marker into the marker list
    def save_satellite_marker(self, satAddress):
        print("inside Save_satellite_marker() \n")
        self.marker_list.append(satAddress)
        # print("Marker_list value {}".format(self.marker_list))
        if satAddress is not None:
            self.marker_list_box.insert(
                tkinter.END, f" {len(self.marker_list)}. {satAddress} ")
            self.marker_list_box.see(tkinter.END)
            self.marker_list.append(self.search_marker)


    def clear_marker_list(self):
        for marker in self.marker_list:
            self.map_widget.delete(marker)

        self.marker_list_box.delete(0, tkinter.END)
        self.marker_list.clear()
        self.connect_marker()

    def connect_marker(self):
        print("\tInside connect_marker() \n")
        # print("\t\tprinting the marker_List \n {}".format(self.marker_list) )
        position_list = []

        for marker in self.marker_list:
            position_list.append(marker.position)

        if self.marker_path is not None:
            self.map_widget.delete(self.marker_path)

        if len(position_list) > 0:
            print("+++++++ . Printing Connect Marker position List here {}".format(position_list))
            self.marker_path = self.map_widget.set_path(position_list)

    def checkBlackzone(self):
        print("\t\tInside checkBlackzone() \n")


    def clear(self):
        self.search_bar.delete(0, last=tkinter.END)
        self.map_widget.delete(self.search_marker)

    def on_closing(self, event=0):
        self.destroy()
        exit()

    def start(self):
        self.mainloop()


 # Function to make HTTP requests 
    def get_satellite_coordinates(self):  # , latitude , longitude
        print("Inside get_Satellite_coordinates() \n")
        print( "*********   Printing input latitude and longitude @ Timestamp \n.")
        for i in self.positions:
            print(type(i))
            for j in i.get('positions'):
                # print(j)

            # for i in self.positions.get('positions'):
                latitude = (j.get('satlatitude'))
                longitude =(j.get('satlongitude'))
                timestamp = dt.datetime.fromtimestamp(j.get('timestamp'))

                print("{} {} @ {}".format(latitude, longitude, timestamp ))
                self.latlong.append((latitude, longitude))
                

        # Reverse Geocoding the latitude and longitude before setting the address down below
                locator = Nominatim(user_agent="sample")
                coordinates = tuple( ( latitude, longitude ))
                location = locator.reverse(coordinates)
                print("Satellite is at ")
                print("{} \t {}".format(coordinates, location))
                self.set_satellite_map_marker(latitude, longitude, timestamp)

                satAddress = location

                self.save_satellite_marker(satAddress)
                print("Just got out of save_satellite_marker()")
        # print(self.latlong)
        keys = ["latitude", "longitude"]
        values = self.latlong
        # [(37.7749, -122.4194), (40.7128, -74.0060), (51.5074, -0.1278)]
        AllLatLongData = dict(map(lambda key, val: (key, list(val)), keys, zip(*values)))
        print(AllLatLongData)
        print(" Current Position is {}".format( (satlAboveHead.Currentlatitude, satlAboveHead.Currentlongitude) ))
        if (satlAboveHead.Currentlatitude in range(int(np.min(AllLatLongData["latitude"])), int(np.max(AllLatLongData["latitude"]))) or 
            satlAboveHead.Currentlongitude in range(int(np.min(AllLatLongData["longitude"])), int(np.max(AllLatLongData["longitude"])))):
            print(" ++!+!+!+!+!+!@#@$$@$@#  There is a satellite on top of your head, You are not in Black out Zone")

    # This function is to set markers based on the lat and long for 150 min duration
    def set_satellite_map_marker(self, lat, long, timeStamp):
        
        self.map_widget.set_marker(lat, long, timeStamp)
        return
   
if __name__ == "__main__":
    app = App()
    app.start()
# Out:
# *********   Printing input samba, jammu 	 latitude and longitude  32.57591175 75.12034455530063
#
#  inside Save_Marker()
#
# *********   Printing input kathua 	 latitude and longitude  32.4288215 75.56286458392415
#
#  inside Save_Marker()
#
# 	Inside connect_marker()
#
# +++++++ . Printing Connect Marker position List here [(32.57591175, 75.12034455530063), (32.4288215, 75.56286458392415)]
# Inside get_Satellite_coordinates()
#
# *********   Printing input latitude and longitude @ Timestamp
# .
# <class 'dict'>
# 43.62246799 64.6678129 @ 2023-06-13 12:19:52
# Satellite is at
# (43.62246799, 64.6678129) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.57053091 64.70162774 @ 2023-06-13 12:19:53
# Satellite is at
# (43.57053091, 64.70162774) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.5185785 64.7353789 @ 2023-06-13 12:19:54
# Satellite is at
# (43.5185785, 64.7353789) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.46661499 64.76906388 @ 2023-06-13 12:19:55
# Satellite is at
# (43.46661499, 64.76906388) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.41463832 64.80268426 @ 2023-06-13 12:19:56
# Satellite is at
# (43.41463832, 64.80268426) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.36264854 64.83624023 @ 2023-06-13 12:19:57
# Satellite is at
# (43.36264854, 64.83624023) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.31064569 64.86973201 @ 2023-06-13 12:19:58
# Satellite is at
# (43.31064569, 64.86973201) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.25862983 64.90315982 @ 2023-06-13 12:19:59
# Satellite is at
# (43.25862983, 64.90315982) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.20660098 64.93652386 @ 2023-06-13 12:20:00
# Satellite is at
# (43.20660098, 64.93652386) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.1545571 64.96982568 @ 2023-06-13 12:20:01
# Satellite is at
# (43.1545571, 64.96982568) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.10250243 65.00306281 @ 2023-06-13 12:20:02
# Satellite is at
# (43.10250243, 65.00306281) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 43.0504349 65.03623679 @ 2023-06-13 12:20:03
# Satellite is at
# (43.0504349, 65.03623679) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.99835457 65.06934783 @ 2023-06-13 12:20:04
# Satellite is at
# (42.99835457, 65.06934783) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.94626147 65.10239614 @ 2023-06-13 12:20:05
# Satellite is at
# (42.94626147, 65.10239614) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.89415565 65.13538192 @ 2023-06-13 12:20:06
# Satellite is at
# (42.89415565, 65.13538192) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.84203714 65.16830537 @ 2023-06-13 12:20:07
# Satellite is at
# (42.84203714, 65.16830537) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.7899039 65.20116803 @ 2023-06-13 12:20:08
# Satellite is at
# (42.7899039, 65.20116803) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.73776015 65.23396745 @ 2023-06-13 12:20:09
# Satellite is at
# (42.73776015, 65.23396745) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.68560385 65.26670515 @ 2023-06-13 12:20:10
# Satellite is at
# (42.68560385, 65.26670515) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.63343504 65.29938133 @ 2023-06-13 12:20:11
# Satellite is at
# (42.63343504, 65.29938133) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.58125375 65.3319962 @ 2023-06-13 12:20:12
# Satellite is at
# (42.58125375, 65.3319962) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.52906002 65.36454995 @ 2023-06-13 12:20:13
# Satellite is at
# (42.52906002, 65.36454995) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.47685391 65.39704279 @ 2023-06-13 12:20:14
# Satellite is at
# (42.47685391, 65.39704279) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.42463334 65.42947622 @ 2023-06-13 12:20:15
# Satellite is at
# (42.42463334, 65.42947622) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.37240466 65.46184651 @ 2023-06-13 12:20:16
# Satellite is at
# (42.37240466, 65.46184651) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.32015951 65.49415909 @ 2023-06-13 12:20:17
# Satellite is at
# (42.32015951, 65.49415909) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42.26790423 65.52641024 @ 2023-06-13 12:20:18
# Satellite is at
# (42.26790423, 65.52641024) 	 Tomdi tumani, Navoiy Viloyati, 210805, Oʻzbekiston
# inside Save_satellite_marker()
#
# Just got out of save_satellite_marker()
# 42